# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from itertools import permutations, product
import random

# %% [markdown]
# lavorare su sample
# calcolare grandezze edge solo all'inizio o dopo tot iterazioni

# %%
# Import edges dataset.
edges = pd.read_csv("c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/edges.csv", usecols=['edge','count','source','target','source_class','target_class'])
# Import edges dataset with time indicators.
edges_complete = pd.read_csv("c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/edges_complete.csv", usecols=['date','source','target'])
# Import dataframe to link authors to their classes.
author_class = pd.read_csv("c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/author_class.csv", usecols=['author','class','i_or_e'])

# %%
authors = author_class['author'].unique()

# %%
edges_complete = edges_complete[edges_complete['source'].isin(authors) & edges_complete['target'].isin(authors)]

# %%
# Remove autoloop
edges = edges[~(edges['source'] == edges['target'])]
edges_complete = edges_complete[~(edges_complete['source'] == edges_complete['target'])]

# %%
# Create the column 'year'.
edges_complete['year'] = edges_complete['date'].apply(lambda x: x[:4])
# Keep only 2022 interactions.
edges_complete = edges_complete[edges_complete['year'].isin(['2022'])]

# %%
edges_duration = edges_complete.copy()
edges_duration['edge'] = edges_duration.apply(lambda row: {row['source'], row['target']}, axis=1)
edges_duration['edge'] = edges_duration['edge'].apply(frozenset)
edge_counts = edges_duration['edge'].value_counts()
edges_duration['count'] = edges_duration['edge'].map(edge_counts)
edges_duration['date'] = pd.to_datetime(edges_duration['date'])
duration = edges_duration.groupby('edge')['date'].agg(lambda x: x.max() - x.min())
# Map the durations back to the original DataFrame
edges_duration['duration'] = edges_duration['edge'].map(duration)

# %%
edges_duration = edges_duration.drop_duplicates('edge').drop(columns=['date'])
edges_duration['edge'] = edges_duration['edge'].apply(list)

# %%
edges_duration.sort_values('count',ascending=False)
# Out:
#                      source           target  year  \
# 437953              111god7           biwaly  2022
# 626251      Either-Fig-9343  Deep_Craft_3760  2022
# 612266     rationalistGamma      Sad_Ad_2243  2022
# 430459  astral_projections_       thatdude2_  2022
# 392884      happilypoisoned        CaveManta  2022
# ...                     ...              ...   ...
# 487654         CatMaster113        7vincent7  2022
# 487653         Flumphs_Lair        7vincent7  2022
# 487652            Le_rascal        7vincent7  2022
# 487649        exhaustedw3eb       randomistp  2022
# 645235      Deep_Craft_3760        GigiJenga  2022
#
#                                       edge  count          duration
# 437953                   [biwaly, 111god7]    152   8 days 16:37:14
# 626251  [Either-Fig-9343, Deep_Craft_3760]    131   0 days 05:55:42
# 612266     [Sad_Ad_2243, rationalistGamma]    100  39 days 19:38:25
# 430459   [astral_projections_, thatdude2_]     97  26 days 14:08:48
# 392884        [CaveManta, happilypoisoned]     93 123 days 16:38:35
# ...                                    ...    ...               ...
# 487654           [7vincent7, CatMaster113]      1   0 days 00:00:00
# 487653           [Flumphs_Lair, 7vincent7]      1   0 days 00:00:00
# 487652              [7vincent7, Le_rascal]      1   0 days 00:00:00
# 487649         [randomistp, exhaustedw3eb]      1   0 days 00:00:00
# 645235        [GigiJenga, Deep_Craft_3760]      1   0 days 00:00:00
#
# [147240 rows x 6 columns]

# %%
edges_dataframe = edges_duration.copy()
# Create the undirected weighted graph.
G = nx.Graph()
for elem, weight in zip(edges_dataframe['edge'].values.tolist(),edges_dataframe[['count', 'duration']].values.tolist()):
    G.add_edge(elem[0], elem[1], weight=weight[0], duration=weight[1].seconds)

# %%
print(f'number of nodes = {G.number_of_nodes()}')
print(f'number of edges = {G.number_of_edges()}')
print(f'number of bridges = {len(list(nx.bridges(G)))}')
print(f'number of components = {nx.number_connected_components(G)}')
# Out:
# number of nodes = 14820
# number of edges = 147240
# number of bridges = 2910
# number of components = 10

# %%
# Find all connected components
components = nx.connected_components(G)

# Get the largest component
largest_component = max(components, key=len)

# Create a subgraph with the largest component
largest_subgraph = G.subgraph(largest_component).copy()

# %%
print(f'number of nodes = {largest_subgraph.number_of_nodes()}')
print(f'number of edges = {largest_subgraph.number_of_edges()}')
print(f'number of bridges = {len(list(nx.bridges(largest_subgraph)))}')
print(f'number of components = {nx.number_connected_components(largest_subgraph)}')
# Out:
# number of nodes = 14801
# number of edges = 147230
# number of bridges = 2900
# number of components = 1

# %% [markdown]
# Complete network:
# + number of nodes = 26809
# + number of edges = 367695
#
# Only 2022 network:
# + number of nodes = 14820
# + number of edges = 147240
#
# Largest connected component 2021-2022:

# %%
G = largest_subgraph.copy()

# %%
def node_overlap(g):
    for u, v in g.edges():
        n_u = set(g.neighbors(u)) # set of u neighbors
        n_v = set(g.neighbors(v)) # set of v neighbors
        overlap = len(n_u & n_v) / len(n_u | n_v) # Neighborhood Overlap
        g[u][v]['overlap'] = overlap
    return g

# %%
G = node_overlap(G)

# %%
a = list(G.edges())[2]
G[a[0]][a[1]]
# Out:
# {'weight': 2, 'duration': 34725, 'overlap': 0.024793388429752067}

# %%
# Compute edge betweenness centrality
#edge_betweenness = nx.edge_betweenness_centrality(G)

# %%
# for edge, centrality in edge_betweenness.items():
#     G.edges[edge]['betweenness'] = centrality

# %% [markdown]
# **RANKING**

# %%
# Create a dictionary to link authors to their classes.
author_to_class = author_class.set_index('author')['class'].to_dict()

# %%
# Rank edges by weight
ranked_edges = sorted(G.edges(data=True), key=lambda x: x[2]['weight'], reverse=True)

# Print the ranked edges
print("Edges ranked by weight:")
for rank, (u, v, attrs) in enumerate(ranked_edges, start=1):
    print(f"Rank {rank}: Edge ({u} ({author_to_class[u]}), {v} ({author_to_class[v]})) with attributes {attrs}")
    if rank == 5: break
# Out:
# Edges ranked by weight:
# Rank 1: Edge (111god7 (entp), biwaly (istj)) with attributes {'weight': 152, 'duration': 59834, 'overlap': 0.015360983102918587}
# Rank 2: Edge (Deep_Craft_3760 (intp), Either-Fig-9343 (entp)) with attributes {'weight': 131, 'duration': 21342, 'overlap': 0.015015015015015015}
# Rank 3: Edge (rationalistGamma (entj), Sad_Ad_2243 (enfp)) with attributes {'weight': 100, 'duration': 70705, 'overlap': 0.0912280701754386}
# Rank 4: Edge (thatdude2_ (istp), astral_projections_ (entp)) with attributes {'weight': 97, 'duration': 50928, 'overlap': 0.04524886877828054}
# Rank 5: Edge (happilypoisoned (istp), CaveManta (intp)) with attributes {'weight': 93, 'duration': 59915, 'overlap': 0.10268948655256724}

# %%
# Rank edges by node overlap
ranked_edges = sorted(G.edges(data=True), key=lambda x: x[2]['overlap'], reverse=True)

# Print the ranked edges
print("Edges ranked by node overlap:")
for rank, (u, v, attrs) in enumerate(ranked_edges, start=1):
    print(f"Rank {rank}: Edge ({u} ({author_to_class[u]}), {v} ({author_to_class[v]})) with attributes {attrs}")
    if rank == 5: break
# Out:
# Edges ranked by node overlap:
# Rank 1: Edge (Terminator_Neon (intj), onehundredirection (intj)) with attributes {'weight': 1, 'duration': 0, 'overlap': 0.25}
# Rank 2: Edge (space_ace33 (isfj), katiurna (intj)) with attributes {'weight': 2, 'duration': 1969, 'overlap': 0.25}
# Rank 3: Edge (TheSneakyHider (intp), SetSailToTheStreets (isfp)) with attributes {'weight': 2, 'duration': 59305, 'overlap': 0.25}
# Rank 4: Edge (criminallygorgeous (entp), xxreyna (entj)) with attributes {'weight': 2, 'duration': 2214, 'overlap': 0.23076923076923078}
# Rank 5: Edge (garrafinhael (isfp), 0x51N4 (entp)) with attributes {'weight': 1, 'duration': 0, 'overlap': 0.2222222222222222}

# %%
# # Rank edges by betweenness centrality
# ranked_edges = sorted(G.edges(data=True), key=lambda x: x[2]['betweenness'], reverse=True)

# # Print the ranked edges
# print("Edges ranked by betweenness centrality:")
# for rank, (u, v, attrs) in enumerate(ranked_edges, start=1):
#     print(f"Rank {rank}: Edge ({u} ({author_to_class[u]}), {v} ({author_to_class[v]})) with attributes {attrs}")
#     if rank == 5: break

# %%
# Rank edges by interaction duration
ranked_edges = sorted(G.edges(data=True), key=lambda x: x[2]['duration'], reverse=True)

# Print the ranked edges
print("Edges ranked by interaction duration:")
for rank, (u, v, attrs) in enumerate(ranked_edges, start=1):
    print(f"Rank {rank}: Edge ({u} ({author_to_class[u]}), {v} ({author_to_class[v]})) with attributes {attrs}")
    if rank == 5: break
# Out:
# Edges ranked by interaction duration:
# Rank 1: Edge (ChocolateCakeReturns (intj), Player20310 (infp)) with attributes {'weight': 3, 'duration': 86399, 'overlap': 0.03289473684210526}
# Rank 2: Edge (sapphire-lily (infp), Helpful-Floor-9568 (intp)) with attributes {'weight': 3, 'duration': 86396, 'overlap': 0.014336917562724014}
# Rank 3: Edge (coffee9000000 (entp), anon3896081 (entj)) with attributes {'weight': 4, 'duration': 86396, 'overlap': 0.0035335689045936395}
# Rank 4: Edge (Lover_of_YOU (infp), melody5697 (infp)) with attributes {'weight': 3, 'duration': 86393, 'overlap': 0.007731958762886598}
# Rank 5: Edge (Deep_Craft_3760 (intp), smayley (istp)) with attributes {'weight': 4, 'duration': 86388, 'overlap': 0.01812688821752266}

# %% [markdown]
# **e-e**, **i-e**, **i-i**

# %%
# Rank edges by weight
ranked_edges = sorted(G.edges(data=True), key=lambda x: x[2]['weight'], reverse=True)
ranked_edges = G.edges(data=True)

# %%
e_e = []
i_i = []
e_i = []

for u,v,attrs in ranked_edges:
    if (author_to_class[u][0] == 'e' and author_to_class[v][0] == 'e'): e_e.append(attrs['weight'])
    elif (author_to_class[u][0] == 'i' and author_to_class[v][0] == 'i'): i_i.append(attrs['weight']) 
    else: e_i.append(attrs['weight'])

# %%
print(f'e_e mean = {np.mean(e_e)}')
print(f'e_i mean = {np.mean(e_i)}')
print(f'i_i mean = {np.mean(i_i)}')
# Out:
# e_e mean = 1.7815110217923757
# e_i mean = 1.7346737597090267
# i_i mean = 1.674348006071478

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,3,1)
plt.hist(e_e,bins=50, color='blue')
plt.yscale('log')
plt.subplot(1,3,2)
plt.hist(i_i,bins=50, color='red')
plt.yscale('log')
plt.subplot(1,3,3)
plt.hist(e_i,bins=50, color='green')
plt.yscale('log')

# %%
e_e = []
i_i = []
e_i = []

attr = 'duration'
for u,v,attrs in ranked_edges:
    if (author_to_class[u][0] == 'e' and author_to_class[v][0] == 'e'): e_e.append(attrs[attr])
    elif (author_to_class[u][0] == 'i' and author_to_class[v][0] == 'i'): i_i.append(attrs[attr]) 
    else: e_i.append(attrs[attr])

# %%
print(f'e_e mean = {np.mean(e_e)}')
print(f'e_i mean = {np.mean(e_i)}')
print(f'i_i mean = {np.mean(i_i)}')
# Out:
# e_e mean = 6316.320040193431
# e_i mean = 5990.364396553189
# i_i mean = 5777.0081550986615

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,3,1)
plt.hist(e_e,bins=50, color='blue')
plt.yscale('log')
plt.subplot(1,3,2)
plt.hist(i_i,bins=50, color='red')
plt.yscale('log')
plt.subplot(1,3,3)
plt.hist(e_i,bins=50, color='green')
plt.yscale('log')

# %%
e_e = []
i_i = []
e_i = []

attr = 'overlap'
for u,v,attrs in ranked_edges:
    if (author_to_class[u][0] == 'e' and author_to_class[v][0] == 'e'): e_e.append(attrs[attr])
    elif (author_to_class[u][0] == 'i' and author_to_class[v][0] == 'i'): i_i.append(attrs[attr]) 
    else: e_i.append(attrs[attr])

# %%
print(f'e_e mean = {np.mean(e_e)}')
print(f'e_i mean = {np.mean(e_i)}')
print(f'i_i mean = {np.mean(i_i)}')
# Out:
# e_e mean = 0.02139449110472029
# e_i mean = 0.02161510704304966
# i_i mean = 0.020839523708189034

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,3,1)
plt.hist(e_e,bins=50, color='blue')
plt.yscale('log')
plt.subplot(1,3,2)
plt.hist(i_i,bins=50, color='red')
plt.yscale('log')
plt.subplot(1,3,3)
plt.hist(e_i,bins=50, color='green')
plt.yscale('log')

# %%
ranked_edges = G.edges(data=True)
e_e = []
i_i = []
e_i = []

for u,v,attrs in ranked_edges:
    if (author_to_class[u][0] == 'e' and author_to_class[v][0] == 'e'): e_e.append([attrs['weight'], attrs['overlap'], attrs['duration']])
    elif (author_to_class[u][0] == 'i' and author_to_class[v][0] == 'i'): i_i.append([attrs['weight'], attrs['overlap'], attrs['duration']]) 
    else: e_i.append([attrs['weight'], attrs['overlap'], attrs['duration']])

e_e = np.array(e_e)
e_i = np.array(e_i)
i_i = np.array(i_i)

# %%
xlabel = ['Weight', 'Node Overlap', 'Duration']
title = ['e_e links', 'e_i links', 'i_i links']
plt.figure(figsize=(15,8))
for i in range(3):
    plt.subplot(3,3,3*i+1)
    if i == 0: plt.title(title[0])
    plt.hist(e_e[:,i], bins=50, color='blue')
    plt.ylabel('Number of edges')
    if i == 2: plt.xlabel(xlabel[i])
    plt.yscale('log')

    plt.subplot(3,3,3*i+2)
    if i == 0: plt.title(title[1])
    plt.hist(e_i[:,i], bins=50, color='green')
    plt.ylabel('Number of edges')
    if i == 2: plt.xlabel(xlabel[i])
    plt.yscale('log')

    plt.subplot(3,3,3*i+3)
    if i == 0: plt.title(title[2])
    plt.hist(i_i[:,i], bins=50, color='red')
    plt.ylabel('Number of edges')
    if i == 2: plt.xlabel(xlabel[i])
    plt.yscale('log')

# %%
xlabel = ['Weight', 'Node Overlap', 'Duration']
title = ['Weight', 'Node Overlap', 'Duration']
plt.figure(figsize=(15,8))
for i in range(3):
    plt.subplot(3,3,i+1)
    #plt.title(title[i])
    if i == 0: plt.hist(e_e[:,i], bins=50, color='blue', label=r'$l_{ee}$')
    else: plt.hist(e_e[:,i], bins=50, color='blue')
    plt.axvline(x=np.mean(e_e[:,i]), color='k', linestyle='--', linewidth=1, label=f'mean = {round(np.mean(e_e[:,i]),3)}')
    #if i == 0: plt.ylabel('Number of edges', size=15)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.yscale('log')
    plt.legend(loc='best', fontsize=15)

    plt.subplot(3,3,i+4)
    
    if i == 0: plt.hist(e_i[:,i], bins=50, color='green', label=r'$l_{ie}$')
    else: plt.hist(e_i[:,i], bins=50, color='green')
    plt.axvline(x=np.mean(e_i[:,i]), color='k', linestyle='--', linewidth=1, label=f'mean = {round(np.mean(e_i[:,i]),3)}')
    if i == 0: plt.ylabel('Number of edges', size=18)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.yscale('log')
    plt.legend(loc='best', fontsize=15)

    plt.subplot(3,3,i+7)
    if i == 0: plt.hist(i_i[:,i], bins=50, color='red', label=r'$l_{ii}$')
    else: plt.hist(i_i[:,i], bins=50, color='red')
    plt.axvline(x=np.mean(i_i[:,i]), color='k', linestyle='--', linewidth=1, label=f'mean = {round(np.mean(i_i[:,i]),3)}')
    #plt.text(x=np.mean(i_i[:,i])+np.mean(i_i[:,i])/5,y=np.histogram(i_i[:,i])[0][0], s=f'mean = {np.mean(i_i[:,i])}')
    #if i == 0: plt.ylabel('Number of edges', size=15)
    plt.xlabel(xlabel[i], size=18)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.legend(loc='best', fontsize=15)
    plt.yscale('log')

# %% [markdown]
# We can see that the distributions and their mean values are similiar for each type of interaction (e_e, e_i and i_i), in general.
# As expected removing edges with low node overlap (local bridges) first destroy the network faster
# As anticipated, the initial removal of edges characterized by low node overlap (i.e., local bridges) leads to a more rapid disintegration of the network structure.

# %% [markdown]
# Fare correlazione tra node overlap, weight e duration.

# %%
a = list(G.edges())[2]
G[a[0]][a[1]]
# Out:
# {'weight': 2, 'duration': 34725, 'overlap': 0.024793388429752067}

# %%
data = []
for u, v, attrs in G.edges(data=True):
    data.append([attrs['weight'], attrs['overlap'], attrs['duration']])
    
df = pd.DataFrame(data, columns=['weight', 'overlap', 'duration'])

correlation_matrix = df.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the correlation matrix
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1,annot_kws={"size": 12})
heatmap.set_xticklabels(heatmap.get_xticklabels(), size=14)
heatmap.set_yticklabels(heatmap.get_yticklabels(), size=14)
plt.title('Correlation Matrix of Edge Attributes', size=18)
plt.show()

# %%
# Out:
# array([[1.        , 0.17401748, 0.37682974],
#        [0.17401748, 1.        , 0.128361  ],
#        [0.37682974, 0.128361  , 1.        ]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Example correlation matrix
df = pd.DataFrame(e_e, columns=['weight', 'overlap', 'duration'])

correlation_matrix = df.corr().to_numpy()

# Example additional values
df = pd.DataFrame(e_e, columns=['weight', 'overlap', 'duration'])

additional_values1 = df.corr().to_numpy()

df = pd.DataFrame(i_i, columns=['weight', 'overlap', 'duration'])

additional_values2 = df.corr().to_numpy()

l = [r'$l_{ee}$', r'$l_{ie}$', r'$l_{ii}$']

# Construct the custom annotations
annot = np.empty(correlation_matrix.shape, dtype=object)

for i in range(correlation_matrix.shape[0]):
    for j in range(correlation_matrix.shape[1]):
        if (i == 0) and (j == 0): annot[i, j] = f"{l[0]}: {correlation_matrix[i, j]:.2f}\n{l[1]}: {additional_values1[i, j]:.2f}\n{l[2]}: {additional_values2[i, j]:.2f}"
        else: annot[i, j] = f"{correlation_matrix[i, j]:.2f}\n{additional_values1[i, j]:.2f}\n{additional_values2[i, j]:.2f}"

# Plot the heatmap with custom annotations
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=annot, fmt="", cmap='coolwarm', vmin=-1, vmax=1,
            annot_kws={"size": 12})  # Adjust the font size as needed
# Set custom x and y labels
x_labels = ['Weight', 'Overlap', 'Duration']
y_labels = ['Weight', 'Overlap', 'Duration']
heatmap.set_xticklabels(x_labels, size=14)  # Adjust font size as needed
heatmap.set_yticklabels(y_labels, size=14)  # Adjust font size as needed

plt.title('Correlation Matrix with Multiple Values', size=18)
plt.show()

# %%
e_e = []
e_i = []
i_i = []
for u,v,attrs in ranked_edges:
    if (author_to_class[u][0] == 'e' and author_to_class[v][0] == 'e'): e_e.append([attrs['weight'], attrs['overlap'], attrs['duration']])
    elif (author_to_class[u][0] == 'i' and author_to_class[v][0] == 'i'): i_i.append([attrs['weight'], attrs['overlap'], attrs['duration']]) 
    else: e_i.append([attrs['weight'], attrs['overlap'], attrs['duration']])

# %%
correlation_matrix.to_numpy()
# Out:
# array([[1.        , 0.14833284, 0.43544838],
#        [0.14833284, 1.        , 0.16638773],
#        [0.43544838, 0.16638773, 1.        ]])

# %%
for data in [e_e, e_i, i_i]:

    df = pd.DataFrame(data, columns=['weight', 'overlap', 'duration'])

    correlation_matrix = df.corr()

    # Plot the correlation matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
    plt.title('Correlation Matrix of Edge Attributes')
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Example correlation matrix
correlation_matrix = np.array([
    [1, 0.14, 0.4],
    [0.14, 1, 0.15],
    [0.4, 0.15, 1]
])

# Example additional values
additional_values1 = np.array([
    [0.5, 0.2, 0.3],
    [0.2, 0.6, 0.1],
    [0.3, 0.1, 0.7]
])

additional_values2 = np.array([
    [0.9, 0.3, 0.5],
    [0.3, 0.8, 0.4],
    [0.5, 0.4, 0.6]
])

# Construct the custom annotations
annot = np.empty(correlation_matrix.shape, dtype=object)

for i in range(correlation_matrix.shape[0]):
    for j in range(correlation_matrix.shape[1]):
        annot[i, j] = f"{correlation_matrix[i, j]:.2f}\n{additional_values1[i, j]:.2f}\n{additional_values2[i, j]:.2f}"

# Plot the heatmap with custom annotations
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=annot, fmt="", cmap='coolwarm', vmin=-1, vmax=1,
            annot_kws={"size": 10})  # Adjust the font size as needed

plt.title('Correlation Matrix with Multiple Values', size=18)
plt.show()

# %% [markdown]
# **NETWORK RESILIANCE**

# %%
import time

def random_edge(g): # select a random node from graph
    return random.choice(list(g.edges()))

def best_score_edge(g, score):
    tmp = sorted(g.edges(data=True), key=lambda x: x[2][score], reverse=True)
    return (tmp[0][0], tmp[0][1])

def dismantle_edge(g, function, **args): # incrementally removes edges from a graph and computes size of connected components
    total_edges = g.number_of_edges()
    removed_edges = []
    components = []
    while g.number_of_edges() > 1:
        if g.number_of_edges() % 1000 == 0: print(f'edges = {g.number_of_edges()}, total edges = {total_edges}')
        t00 = time.time()
        e = function(g, **args)
        #print(f'Elapsed time function = {time.time()-t00}')
        #t0 = time.time()
        g.remove_edge(*e)
        #print(f'Elapsed time edge removal = {time.time()-t0}')

        removed_edges.append((len(removed_edges)+1)/total_edges)
        #t0 = time.time()
        comps = list(nx.connected_components(g))
        #print(f'Elapsed time connected_components = {time.time()-t0}')
        g_size = 0
        # if len(comps)>0:
        g_size  = max([len(c)for c in comps])/total_edges
        components.append(g_size)
        print(f'Elapsed time = {time.time()-t00}')
    return removed_edges, components


def dismantle_edge_overlap(g, repeat_rank = 1000, reverse=True): # incrementally removes edges from a graph and computes size of connected components
    total_edges = g.number_of_edges()
    removed_edges = []
    components = []
    g = node_overlap(g)
    ranked_edges = sorted(g.edges(data=True), key=lambda x: x[2]['overlap'], reverse=reverse)
    i = 0
    t0 = time.time()
    while i < (total_edges):
        if i % 1000 == 0:
            print(f'removed edges = {i}, total edges = {total_edges}, elasped_time = {time.time()-t0}')
            t0 = time.time()
        #t00 = time.time()
        if i % repeat_rank == 0:
            g = node_overlap(g)
            ranked_edges = sorted(g.edges(data=True), key=lambda x: x[2]['overlap'], reverse=reverse)
            print(f'ranked_edges updated')

        e = ranked_edges.pop(0)
        #print(f'Elapsed time function = {time.time()-t00}')
        #t0 = time.time()
        g.remove_edge(e[0],e[1])
        #print(f'Elapsed time edge removal = {time.time()-t0}')
        i += 1
        removed_edges.append(i/total_edges)
        #t0 = time.time()
        comps = list(nx.connected_components(g))
        #print(f'Elapsed time connected_components = {time.time()-t0}')
        g_size = 0
        # if len(comps)>0:
        g_size  = max([len(c)for c in comps])/total_edges
        components.append(g_size)
        #print(f'Elapsed time = {time.time()-t00}')
    return removed_edges, components

def dismantle_edge_score(g, score, reverse=True): # incrementally removes edges from a graph and computes size of connected components
    total_edges = g.number_of_edges()
    removed_edges = []
    components = []
    ranked_edges = sorted(g.edges(data=True), key=lambda x: x[2][score], reverse=reverse)
    i = 0
    t0 = time.time()
    while i < (total_edges):
        if i % 1000 == 0:
            print(f'removed edges = {i}, total edges = {total_edges}, elapsed_time = {time.time()-t0}')
            t0 = time.time()
        #t00 = time.time()
        e = ranked_edges.pop(0)
        #print(f'Elapsed time function = {time.time()-t00}')
        #t0 = time.time()
        g.remove_edge(e[0],e[1])
        #print(f'Elapsed time edge removal = {time.time()-t0}')
        i += 1
        removed_edges.append(i/total_edges)
        #t0 = time.time()
        comps = list(nx.connected_components(g))
        #print(f'Elapsed time connected_components = {time.time()-t0}')
        g_size = 0
        # if len(comps)>0:
        g_size  = max([len(c)for c in comps])/total_edges
        components.append(g_size)
        #print(f'Elapsed time = {time.time()-t00}')
    return removed_edges, components

def dismantle_edge_random(g): # incrementally removes edges from a graph and computes size of connected components
    total_edges = g.number_of_edges()
    removed_edges = []
    components = []
    i = 0
    t0 = time.time()
    random_list = list(g.edges())
    random.shuffle(random_list)
    while i < (total_edges):
        if i % 1000 == 0:
            print(f'removed edges = {i}, total edges = {total_edges}, elapsed_time = {time.time()-t0}')
            t0 = time.time()
        #t00 = time.time()
        e = random_list.pop(0)
        #print(f'Elapsed time function = {time.time()-t00}')
        #t0 = time.time()
        g.remove_edge(e[0],e[1])
        #print(f'Elapsed time edge removal = {time.time()-t0}')
        i += 1
        removed_edges.append(i/total_edges)
        #t0 = time.time()
        comps = list(nx.connected_components(g))
        #print(f'Elapsed time connected_components = {time.time()-t0}')
        g_size = 0
        # if len(comps)>0:
        g_size  = max([len(c)for c in comps])/total_edges
        components.append(g_size)
        #print(f'Elapsed time = {time.time()-t00}')
    return removed_edges, components

def plot_dismantle(x, y):
    plt.figure(figsize=(15,8))
    plt.plot(x, y)
    plt.xlabel("Removed Edges")
    plt.ylabel("Giant Component size")
    plt.show()

# %%
h = G.copy()
rn, comps = dismantle_edge_random(h)
plot_dismantle(rn, comps)
# Out:
# removed edges = 0, total edges = 147230, elapsed_time = 0.13445496559143066
# removed edges = 1000, total edges = 147230, elapsed_time = 41.82390284538269
# removed edges = 2000, total edges = 147230, elapsed_time = 41.65972399711609
# removed edges = 3000, total edges = 147230, elapsed_time = 41.099377393722534
# removed edges = 4000, total edges = 147230, elapsed_time = 41.50656986236572
# removed edges = 5000, total edges = 147230, elapsed_time = 41.03769850730896
# removed edges = 6000, total edges = 147230, elapsed_time = 41.23769688606262
# removed edges = 7000, total edges = 147230, elapsed_time = 40.021299600601196
# removed edges = 8000, total edges = 147230, elapsed_time = 41.20070838928223
# removed edges = 9000, total edges = 147230, elapsed_time = 40.33394813537598
# removed edges = 10000, total edges = 147230, elapsed_time = 42.28634834289551
# removed edges = 11000, total edges = 147230, elapsed_time = 39.91377925872803
# removed edges = 12000, total edges = 147230, elapsed_time = 40.82108426094055
# removed edges = 13000, total edges = 147230, elapsed_time = 40.45623183250427
# removed edges = 14000, total edges = 147230, elapsed_time = 40.02198576927185
# removed edges = 15000, total edges = 147230, elapsed_time = 41.31568694114685
# removed edges = 16000, total edges = 147230, elapsed_time = 42.34790635108948
pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(comps, file)

# %%
h = G.copy()
rn, comps = dismantle_edge_overlap(h, repeat_rank = 1000, reverse= True)
plot_dismantle(rn, comps)
# Out:
# removed edges = 0, total edges = 147230, elasped_time = 0.0
# ranked_edges updated
# removed edges = 1000, total edges = 147230, elasped_time = 45.87699294090271
# ranked_edges updated
# removed edges = 2000, total edges = 147230, elasped_time = 46.38887548446655
# ranked_edges updated
# removed edges = 3000, total edges = 147230, elasped_time = 46.03261923789978
# ranked_edges updated
# removed edges = 4000, total edges = 147230, elasped_time = 66.65208649635315
# ranked_edges updated
# removed edges = 5000, total edges = 147230, elasped_time = 88.59942579269409
# ranked_edges updated
# removed edges = 6000, total edges = 147230, elasped_time = 86.87066984176636
# ranked_edges updated
# removed edges = 7000, total edges = 147230, elasped_time = 85.61857867240906
# ranked_edges updated
# removed edges = 8000, total edges = 147230, elasped_time = 86.55860447883606
# ranked_edges updated
# removed edges = 9000, total edges = 147230, elasped_time = 85.69751501083374
# ranked_edges updated
# removed edges = 10000, total edges = 147230, elasped_time = 82.84055757522583
# ranked_edges updated
# removed edges = 11000, total edges = 147230, elasped_time = 92.64135837554932
# ranked_edges updated
# removed edges = 12000, total edges = 147230, elasped_time = 79.28734064102173
# ranked_edges updated
# removed edges = 13000, total edges = 147230, elasped_time = 71.12453818321228
# ranked_edges updated
# removed edges = 14000, total edges = 147230, elasped_time = 72.70348906517029
# ranked_edges updated
# removed edges = 15000, total edges = 147230, elasped_time = 69.46525287628174
# ranked_edges updated
# removed edges = 16000, total edges = 147230, elasped_time = 70.24576091766357
# ranked_edges updated
# removed edges = 17000, total edges = 147230, elasped_time = 70.44869303703308
# ranked_edges updated
# removed edges = 18000, total edges = 147230, elasped_time = 63.59065628051758
# ranked_edges updated
# removed edges = 19000, total edges = 147230, elasped_time = 42.49332118034363
# ranked_edges updated
# removed edges = 20000, total edges = 147230, elasped_time = 44.08637976646423
# ranked_edges updated
# removed edges = 21000, total edges = 147230, elasped_time = 42.18969774246216
# ranked_edges updated
# removed edges = 22000, total edges = 147230, elasped_time = 41.64993238449097
# ranked_edges updated
# removed edges = 23000, total edges = 147230, elasped_time = 59.02471876144409
# ranked_edges updated
# removed edges = 24000, total edges = 147230, elasped_time = 82.63515400886536
# ranked_edges updated
# removed edges = 25000, total edges = 147230, elasped_time = 78.05202102661133
# ranked_edges updated
# removed edges = 26000, total edges = 147230, elasped_time = 56.99824500083923
# ranked_edges updated
# removed edges = 27000, total edges = 147230, elasped_time = 52.95359492301941
# ranked_edges updated
# removed edges = 28000, total edges = 147230, elasped_time = 50.36328864097595
# ranked_edges updated
# removed edges = 29000, total edges = 147230, elasped_time = 44.51128792762756
# ranked_edges updated
# removed edges = 30000, total edges = 147230, elasped_time = 37.802515268325806
# ranked_edges updated
# removed edges = 31000, total edges = 147230, elasped_time = 38.55272197723389
# ranked_edges updated
# removed edges = 32000, total edges = 147230, elasped_time = 36.29694700241089
# ranked_edges updated
# removed edges = 33000, total edges = 147230, elasped_time = 40.870014667510986
# ranked_edges updated
# removed edges = 34000, total edges = 147230, elasped_time = 39.591795444488525
# ranked_edges updated
# removed edges = 35000, total edges = 147230, elasped_time = 37.78350901603699
# ranked_edges updated
# removed edges = 36000, total edges = 147230, elasped_time = 38.39065623283386
# ranked_edges updated
# removed edges = 37000, total edges = 147230, elasped_time = 36.5625376701355
# ranked_edges updated
# removed edges = 38000, total edges = 147230, elasped_time = 37.394933223724365
# ranked_edges updated
# removed edges = 39000, total edges = 147230, elasped_time = 38.58699107170105
# ranked_edges updated
# removed edges = 40000, total edges = 147230, elasped_time = 35.7147171497345
# ranked_edges updated
# removed edges = 41000, total edges = 147230, elasped_time = 34.5555853843689
# ranked_edges updated
# removed edges = 42000, total edges = 147230, elasped_time = 35.690430641174316
# ranked_edges updated
# removed edges = 43000, total edges = 147230, elasped_time = 39.39792799949646
# ranked_edges updated
# removed edges = 44000, total edges = 147230, elasped_time = 45.96039700508118
# ranked_edges updated
# removed edges = 45000, total edges = 147230, elasped_time = 44.464152336120605
# ranked_edges updated
# removed edges = 46000, total edges = 147230, elasped_time = 51.81868243217468
# ranked_edges updated
# removed edges = 47000, total edges = 147230, elasped_time = 47.002798080444336
# ranked_edges updated
# removed edges = 48000, total edges = 147230, elasped_time = 46.465927839279175
# ranked_edges updated
# removed edges = 49000, total edges = 147230, elasped_time = 45.886215925216675
# ranked_edges updated
# removed edges = 50000, total edges = 147230, elasped_time = 45.69960570335388
# ranked_edges updated
# removed edges = 51000, total edges = 147230, elasped_time = 44.975600719451904
# ranked_edges updated
# removed edges = 52000, total edges = 147230, elasped_time = 37.18593096733093
# ranked_edges updated
# removed edges = 53000, total edges = 147230, elasped_time = 35.62981629371643
# ranked_edges updated
# removed edges = 54000, total edges = 147230, elasped_time = 35.56295418739319
# ranked_edges updated
# removed edges = 55000, total edges = 147230, elasped_time = 36.569796085357666
# ranked_edges updated
# removed edges = 56000, total edges = 147230, elasped_time = 36.111215114593506
# ranked_edges updated
# removed edges = 57000, total edges = 147230, elasped_time = 36.34132146835327
# ranked_edges updated
# removed edges = 58000, total edges = 147230, elasped_time = 32.20294761657715
# ranked_edges updated
# removed edges = 59000, total edges = 147230, elasped_time = 34.47448945045471
# ranked_edges updated
# removed edges = 60000, total edges = 147230, elasped_time = 35.52104735374451
# ranked_edges updated
# removed edges = 61000, total edges = 147230, elasped_time = 32.71927070617676
# ranked_edges updated
# removed edges = 62000, total edges = 147230, elasped_time = 32.738993406295776
# ranked_edges updated
# removed edges = 63000, total edges = 147230, elasped_time = 32.96731352806091
# ranked_edges updated
# removed edges = 64000, total edges = 147230, elasped_time = 34.07817578315735
# ranked_edges updated
# removed edges = 65000, total edges = 147230, elasped_time = 31.911420822143555
# ranked_edges updated
# removed edges = 66000, total edges = 147230, elasped_time = 32.755110025405884
# ranked_edges updated
# removed edges = 67000, total edges = 147230, elasped_time = 33.572012186050415
# ranked_edges updated
# removed edges = 68000, total edges = 147230, elasped_time = 31.743632793426514
# ranked_edges updated
# removed edges = 69000, total edges = 147230, elasped_time = 32.89208769798279
# ranked_edges updated
# removed edges = 70000, total edges = 147230, elasped_time = 30.390431880950928
# ranked_edges updated
# removed edges = 71000, total edges = 147230, elasped_time = 32.59663987159729
# ranked_edges updated
# removed edges = 72000, total edges = 147230, elasped_time = 31.1973614692688
# ranked_edges updated
# removed edges = 73000, total edges = 147230, elasped_time = 33.812514781951904
# ranked_edges updated
# removed edges = 74000, total edges = 147230, elasped_time = 43.544203996658325
# ranked_edges updated
# removed edges = 75000, total edges = 147230, elasped_time = 31.20384955406189
# ranked_edges updated
# removed edges = 76000, total edges = 147230, elasped_time = 30.627399921417236
# ranked_edges updated
# removed edges = 77000, total edges = 147230, elasped_time = 30.752787590026855
# ranked_edges updated
# removed edges = 78000, total edges = 147230, elasped_time = 29.86821460723877
# ranked_edges updated
# removed edges = 79000, total edges = 147230, elasped_time = 31.522557258605957
# ranked_edges updated
# removed edges = 80000, total edges = 147230, elasped_time = 28.69934105873108
# ranked_edges updated
# removed edges = 81000, total edges = 147230, elasped_time = 28.795108795166016
# ranked_edges updated
# removed edges = 82000, total edges = 147230, elasped_time = 29.48858141899109
# ranked_edges updated
# removed edges = 83000, total edges = 147230, elasped_time = 29.292766332626343
# ranked_edges updated
# removed edges = 84000, total edges = 147230, elasped_time = 29.357577800750732
# ranked_edges updated
# removed edges = 85000, total edges = 147230, elasped_time = 28.675132513046265
# ranked_edges updated
# removed edges = 86000, total edges = 147230, elasped_time = 28.925137281417847
# ranked_edges updated
# removed edges = 87000, total edges = 147230, elasped_time = 28.990071296691895
# ranked_edges updated
# removed edges = 88000, total edges = 147230, elasped_time = 29.785862922668457
# ranked_edges updated
# removed edges = 89000, total edges = 147230, elasped_time = 30.35972023010254
# ranked_edges updated
# removed edges = 90000, total edges = 147230, elasped_time = 29.079439401626587
# ranked_edges updated
# removed edges = 91000, total edges = 147230, elasped_time = 30.696460485458374
# ranked_edges updated
# removed edges = 92000, total edges = 147230, elasped_time = 29.06031823158264
# ranked_edges updated
# removed edges = 93000, total edges = 147230, elasped_time = 30.035725831985474
# ranked_edges updated
# removed edges = 94000, total edges = 147230, elasped_time = 29.852637767791748
# ranked_edges updated
# removed edges = 95000, total edges = 147230, elasped_time = 30.695943117141724
# ranked_edges updated
# removed edges = 96000, total edges = 147230, elasped_time = 30.23503303527832
# ranked_edges updated
# removed edges = 97000, total edges = 147230, elasped_time = 29.376405477523804
# ranked_edges updated
# removed edges = 98000, total edges = 147230, elasped_time = 30.000123739242554
# ranked_edges updated
# removed edges = 99000, total edges = 147230, elasped_time = 31.11633825302124
# ranked_edges updated
# removed edges = 100000, total edges = 147230, elasped_time = 32.93201780319214
# ranked_edges updated
# removed edges = 101000, total edges = 147230, elasped_time = 31.563939809799194
# ranked_edges updated
# removed edges = 102000, total edges = 147230, elasped_time = 32.089253664016724
# ranked_edges updated
# removed edges = 103000, total edges = 147230, elasped_time = 31.523194551467896
# ranked_edges updated
# removed edges = 104000, total edges = 147230, elasped_time = 32.54683971405029
# ranked_edges updated
# removed edges = 105000, total edges = 147230, elasped_time = 33.52731943130493
# ranked_edges updated
# removed edges = 106000, total edges = 147230, elasped_time = 32.5296049118042
# ranked_edges updated
# removed edges = 107000, total edges = 147230, elasped_time = 33.46891260147095
# ranked_edges updated
# removed edges = 108000, total edges = 147230, elasped_time = 34.55348873138428
# ranked_edges updated
# removed edges = 109000, total edges = 147230, elasped_time = 33.86874198913574
# ranked_edges updated
# removed edges = 110000, total edges = 147230, elasped_time = 34.753732204437256
# ranked_edges updated
# removed edges = 111000, total edges = 147230, elasped_time = 35.205349922180176
# ranked_edges updated
# removed edges = 112000, total edges = 147230, elasped_time = 35.44801735877991
# ranked_edges updated
# removed edges = 113000, total edges = 147230, elasped_time = 35.988178730010986
# ranked_edges updated
# removed edges = 114000, total edges = 147230, elasped_time = 35.713820457458496
# ranked_edges updated
# removed edges = 115000, total edges = 147230, elasped_time = 35.229639291763306
# ranked_edges updated
# removed edges = 116000, total edges = 147230, elasped_time = 37.10184383392334
# ranked_edges updated
# removed edges = 117000, total edges = 147230, elasped_time = 37.94334673881531
# ranked_edges updated
# removed edges = 118000, total edges = 147230, elasped_time = 37.28990817070007
# ranked_edges updated
# removed edges = 119000, total edges = 147230, elasped_time = 37.67001128196716
# ranked_edges updated
# removed edges = 120000, total edges = 147230, elasped_time = 38.60098576545715
# ranked_edges updated
# removed edges = 121000, total edges = 147230, elasped_time = 38.18187475204468
# ranked_edges updated
# removed edges = 122000, total edges = 147230, elasped_time = 39.321860551834106
# ranked_edges updated
# removed edges = 123000, total edges = 147230, elasped_time = 39.40152025222778
# ranked_edges updated
# removed edges = 124000, total edges = 147230, elasped_time = 39.890689849853516
# ranked_edges updated
# removed edges = 125000, total edges = 147230, elasped_time = 39.86029028892517
# ranked_edges updated
# removed edges = 126000, total edges = 147230, elasped_time = 40.3731689453125
# ranked_edges updated
# removed edges = 127000, total edges = 147230, elasped_time = 40.860103368759155
# ranked_edges updated
# removed edges = 128000, total edges = 147230, elasped_time = 40.837780714035034
# ranked_edges updated
# removed edges = 129000, total edges = 147230, elasped_time = 41.16065502166748
# ranked_edges updated
# removed edges = 130000, total edges = 147230, elasped_time = 41.15301704406738
# ranked_edges updated
# removed edges = 131000, total edges = 147230, elasped_time = 41.03461790084839
# ranked_edges updated
# removed edges = 132000, total edges = 147230, elasped_time = 41.91318440437317
# ranked_edges updated
# removed edges = 133000, total edges = 147230, elasped_time = 42.04432010650635
# ranked_edges updated
# removed edges = 134000, total edges = 147230, elasped_time = 42.340818643569946
# ranked_edges updated
# removed edges = 135000, total edges = 147230, elasped_time = 43.504188537597656
# ranked_edges updated
# removed edges = 136000, total edges = 147230, elasped_time = 43.56551790237427
# ranked_edges updated
# removed edges = 137000, total edges = 147230, elasped_time = 43.69109320640564
# ranked_edges updated
# removed edges = 138000, total edges = 147230, elasped_time = 44.91916799545288
# ranked_edges updated
# removed edges = 139000, total edges = 147230, elasped_time = 44.76494359970093
# ranked_edges updated
# removed edges = 140000, total edges = 147230, elasped_time = 45.26268792152405
# ranked_edges updated
# removed edges = 141000, total edges = 147230, elasped_time = 46.24984169006348
# ranked_edges updated
# removed edges = 142000, total edges = 147230, elasped_time = 46.667542695999146
# ranked_edges updated
# removed edges = 143000, total edges = 147230, elasped_time = 47.29175925254822
# ranked_edges updated
# removed edges = 144000, total edges = 147230, elasped_time = 48.38343286514282
# ranked_edges updated
# removed edges = 145000, total edges = 147230, elasped_time = 48.893768548965454
# ranked_edges updated
# removed edges = 146000, total edges = 147230, elasped_time = 49.78526496887207
# ranked_edges updated
# removed edges = 147000, total edges = 147230, elasped_time = 49.784770488739014
# ranked_edges updated

# %%
import pickle
dir = "c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/"

with open(f'{dir}removed_edges_overlap_decreasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(rn, file)

with open(f'{dir}components_overlap_decreasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(comps, file)

# %%
h = G.copy()
rn, comps = dismantle_edge_overlap(h, repeat_rank = 1000, reverse= False)
plot_dismantle(rn, comps)
# Out:
# removed edges = 0, total edges = 147230, elasped_time = 0.0
# ranked_edges updated
# removed edges = 1000, total edges = 147230, elasped_time = 43.04831314086914
# ranked_edges updated
# removed edges = 2000, total edges = 147230, elasped_time = 46.50329947471619
# ranked_edges updated
# removed edges = 3000, total edges = 147230, elasped_time = 42.777379274368286
# ranked_edges updated
# removed edges = 4000, total edges = 147230, elasped_time = 42.759241580963135
# ranked_edges updated
# removed edges = 5000, total edges = 147230, elasped_time = 44.794095516204834
# ranked_edges updated
# removed edges = 6000, total edges = 147230, elasped_time = 45.56243181228638
# ranked_edges updated
# removed edges = 7000, total edges = 147230, elasped_time = 46.904325008392334
# ranked_edges updated
# removed edges = 8000, total edges = 147230, elasped_time = 45.576231956481934
# ranked_edges updated
# removed edges = 9000, total edges = 147230, elasped_time = 44.23594689369202
# ranked_edges updated
# removed edges = 10000, total edges = 147230, elasped_time = 44.641627073287964
# ranked_edges updated
# removed edges = 11000, total edges = 147230, elasped_time = 48.53128480911255
# ranked_edges updated
# removed edges = 12000, total edges = 147230, elasped_time = 44.65280365943909
# ranked_edges updated
# removed edges = 13000, total edges = 147230, elasped_time = 47.101609230041504
# ranked_edges updated
# removed edges = 14000, total edges = 147230, elasped_time = 45.53953313827515
# ranked_edges updated
# removed edges = 15000, total edges = 147230, elasped_time = 45.45734667778015
# ranked_edges updated
# removed edges = 16000, total edges = 147230, elasped_time = 45.83378028869629
# ranked_edges updated
# removed edges = 17000, total edges = 147230, elasped_time = 48.11049818992615
# ranked_edges updated
# removed edges = 18000, total edges = 147230, elasped_time = 47.91311454772949
# ranked_edges updated
# removed edges = 19000, total edges = 147230, elasped_time = 48.01157999038696
# ranked_edges updated
# removed edges = 20000, total edges = 147230, elasped_time = 48.2788143157959
# ranked_edges updated
# removed edges = 21000, total edges = 147230, elasped_time = 45.29671907424927
# ranked_edges updated
# removed edges = 22000, total edges = 147230, elasped_time = 49.68871212005615
# ranked_edges updated
# removed edges = 23000, total edges = 147230, elasped_time = 49.538230657577515
# ranked_edges updated
# removed edges = 24000, total edges = 147230, elasped_time = 48.14941644668579
# ranked_edges updated
# removed edges = 25000, total edges = 147230, elasped_time = 47.906283140182495
# ranked_edges updated
# removed edges = 26000, total edges = 147230, elasped_time = 50.14380168914795
# ranked_edges updated
# removed edges = 27000, total edges = 147230, elasped_time = 48.52203416824341
# ranked_edges updated
# removed edges = 28000, total edges = 147230, elasped_time = 49.847805976867676
# ranked_edges updated
# removed edges = 29000, total edges = 147230, elasped_time = 49.60849046707153
# ranked_edges updated
# removed edges = 30000, total edges = 147230, elasped_time = 52.47013258934021
# ranked_edges updated
# removed edges = 31000, total edges = 147230, elasped_time = 50.20582413673401
# ranked_edges updated
# removed edges = 32000, total edges = 147230, elasped_time = 52.53226280212402
# ranked_edges updated
# removed edges = 33000, total edges = 147230, elasped_time = 55.420700550079346
# ranked_edges updated
# removed edges = 34000, total edges = 147230, elasped_time = 54.81841731071472
# ranked_edges updated
# removed edges = 35000, total edges = 147230, elasped_time = 56.619367837905884
# ranked_edges updated
# removed edges = 36000, total edges = 147230, elasped_time = 55.846823930740356
# ranked_edges updated
# removed edges = 37000, total edges = 147230, elasped_time = 55.23817276954651
# ranked_edges updated
# removed edges = 38000, total edges = 147230, elasped_time = 54.7276554107666
# ranked_edges updated
# removed edges = 39000, total edges = 147230, elasped_time = 55.07849049568176
# ranked_edges updated
# removed edges = 40000, total edges = 147230, elasped_time = 55.28731608390808
# ranked_edges updated
# removed edges = 41000, total edges = 147230, elasped_time = 56.371520042419434
# ranked_edges updated
# removed edges = 42000, total edges = 147230, elasped_time = 56.17317461967468
# ranked_edges updated
# removed edges = 43000, total edges = 147230, elasped_time = 56.24132204055786
# ranked_edges updated
# removed edges = 44000, total edges = 147230, elasped_time = 55.82568383216858
# ranked_edges updated
# removed edges = 45000, total edges = 147230, elasped_time = 55.20448684692383
# ranked_edges updated
# removed edges = 46000, total edges = 147230, elasped_time = 56.724002838134766
# ranked_edges updated
# removed edges = 47000, total edges = 147230, elasped_time = 55.47978949546814
# ranked_edges updated
# removed edges = 48000, total edges = 147230, elasped_time = 56.63027358055115
# ranked_edges updated
# removed edges = 49000, total edges = 147230, elasped_time = 56.680846214294434
# ranked_edges updated
# removed edges = 50000, total edges = 147230, elasped_time = 55.47904586791992
# ranked_edges updated
# removed edges = 51000, total edges = 147230, elasped_time = 54.70951056480408
# ranked_edges updated
# removed edges = 52000, total edges = 147230, elasped_time = 56.46362495422363
# ranked_edges updated
# removed edges = 53000, total edges = 147230, elasped_time = 55.87193965911865
# ranked_edges updated
# removed edges = 54000, total edges = 147230, elasped_time = 57.036442279815674
# ranked_edges updated
# removed edges = 55000, total edges = 147230, elasped_time = 56.14788222312927
# ranked_edges updated
# removed edges = 56000, total edges = 147230, elasped_time = 55.487592935562134
# ranked_edges updated
# removed edges = 57000, total edges = 147230, elasped_time = 56.00061821937561
# ranked_edges updated
# removed edges = 58000, total edges = 147230, elasped_time = 55.79229259490967
# ranked_edges updated
# removed edges = 59000, total edges = 147230, elasped_time = 75.35079503059387
# ranked_edges updated
# removed edges = 60000, total edges = 147230, elasped_time = 76.40341687202454
# ranked_edges updated
# removed edges = 61000, total edges = 147230, elasped_time = 69.78278183937073
# ranked_edges updated
# removed edges = 62000, total edges = 147230, elasped_time = 58.26739549636841
# ranked_edges updated
# removed edges = 63000, total edges = 147230, elasped_time = 56.615283250808716
# ranked_edges updated
# removed edges = 64000, total edges = 147230, elasped_time = 55.84355401992798
# ranked_edges updated
# removed edges = 65000, total edges = 147230, elasped_time = 55.88238596916199
# ranked_edges updated
# removed edges = 66000, total edges = 147230, elasped_time = 55.38575863838196
# ranked_edges updated
# removed edges = 67000, total edges = 147230, elasped_time = 55.57160782814026
# ranked_edges updated
# removed edges = 68000, total edges = 147230, elasped_time = 54.62819051742554
# ranked_edges updated
# removed edges = 69000, total edges = 147230, elasped_time = 55.75387477874756
# ranked_edges updated
# removed edges = 70000, total edges = 147230, elasped_time = 54.61916518211365
# ranked_edges updated
# removed edges = 71000, total edges = 147230, elasped_time = 55.42914819717407
# ranked_edges updated
# removed edges = 72000, total edges = 147230, elasped_time = 55.169854402542114
# ranked_edges updated
# removed edges = 73000, total edges = 147230, elasped_time = 53.46565914154053
# ranked_edges updated
# removed edges = 74000, total edges = 147230, elasped_time = 54.54522204399109
# ranked_edges updated
# removed edges = 75000, total edges = 147230, elasped_time = 55.42205286026001
# ranked_edges updated
# removed edges = 76000, total edges = 147230, elasped_time = 53.69664454460144
# ranked_edges updated
# removed edges = 77000, total edges = 147230, elasped_time = 53.38259530067444
# ranked_edges updated
# removed edges = 78000, total edges = 147230, elasped_time = 53.727303981781006
# ranked_edges updated
# removed edges = 79000, total edges = 147230, elasped_time = 53.740838050842285
# ranked_edges updated
# removed edges = 80000, total edges = 147230, elasped_time = 54.72549080848694
# ranked_edges updated
# removed edges = 81000, total edges = 147230, elasped_time = 53.442118644714355
# ranked_edges updated
# removed edges = 82000, total edges = 147230, elasped_time = 54.20534944534302
# ranked_edges updated
# removed edges = 83000, total edges = 147230, elasped_time = 54.32092046737671
# ranked_edges updated
# removed edges = 84000, total edges = 147230, elasped_time = 54.386634349823
# ranked_edges updated
# removed edges = 85000, total edges = 147230, elasped_time = 54.78900671005249
# ranked_edges updated
# removed edges = 86000, total edges = 147230, elasped_time = 53.43470096588135
# ranked_edges updated
# removed edges = 87000, total edges = 147230, elasped_time = 53.50628042221069
# ranked_edges updated
# removed edges = 88000, total edges = 147230, elasped_time = 53.69201588630676
# ranked_edges updated
# removed edges = 89000, total edges = 147230, elasped_time = 52.95820760726929
# ranked_edges updated
# removed edges = 90000, total edges = 147230, elasped_time = 53.5903480052948
# ranked_edges updated
# removed edges = 91000, total edges = 147230, elasped_time = 53.7424476146698
# ranked_edges updated
# removed edges = 92000, total edges = 147230, elasped_time = 53.33280801773071
# ranked_edges updated
# removed edges = 93000, total edges = 147230, elasped_time = 53.84178709983826
# ranked_edges updated
# removed edges = 94000, total edges = 147230, elasped_time = 53.97206902503967
# ranked_edges updated
# removed edges = 95000, total edges = 147230, elasped_time = 53.981547594070435
# ranked_edges updated
# removed edges = 96000, total edges = 147230, elasped_time = 53.68918776512146
# ranked_edges updated
# removed edges = 97000, total edges = 147230, elasped_time = 52.931949853897095
# ranked_edges updated
# removed edges = 98000, total edges = 147230, elasped_time = 52.96477293968201
# ranked_edges updated
# removed edges = 99000, total edges = 147230, elasped_time = 51.922072887420654
# ranked_edges updated
# removed edges = 100000, total edges = 147230, elasped_time = 53.7663209438324
# ranked_edges updated
# removed edges = 101000, total edges = 147230, elasped_time = 52.41436791419983
# ranked_edges updated
# removed edges = 102000, total edges = 147230, elasped_time = 51.465402603149414
# ranked_edges updated
# removed edges = 103000, total edges = 147230, elasped_time = 51.38537526130676
# ranked_edges updated
# removed edges = 104000, total edges = 147230, elasped_time = 51.76435446739197
# ranked_edges updated
# removed edges = 105000, total edges = 147230, elasped_time = 52.04618549346924
# ranked_edges updated
# removed edges = 106000, total edges = 147230, elasped_time = 51.85531306266785
# ranked_edges updated
# removed edges = 107000, total edges = 147230, elasped_time = 52.98114538192749
# ranked_edges updated
# removed edges = 108000, total edges = 147230, elasped_time = 52.14865970611572
# ranked_edges updated
# removed edges = 109000, total edges = 147230, elasped_time = 50.70268797874451
# ranked_edges updated
# removed edges = 110000, total edges = 147230, elasped_time = 51.55593752861023
# ranked_edges updated
# removed edges = 111000, total edges = 147230, elasped_time = 51.30988836288452
# ranked_edges updated
# removed edges = 112000, total edges = 147230, elasped_time = 51.40620231628418
# ranked_edges updated
# removed edges = 113000, total edges = 147230, elasped_time = 51.068695306777954
# ranked_edges updated
# removed edges = 114000, total edges = 147230, elasped_time = 50.61829614639282
# ranked_edges updated
# removed edges = 115000, total edges = 147230, elasped_time = 50.93808102607727
# ranked_edges updated
# removed edges = 116000, total edges = 147230, elasped_time = 50.828227043151855
# ranked_edges updated
# removed edges = 117000, total edges = 147230, elasped_time = 50.971970319747925
# ranked_edges updated
# removed edges = 118000, total edges = 147230, elasped_time = 51.065033197402954
# ranked_edges updated
# removed edges = 119000, total edges = 147230, elasped_time = 51.27536869049072
# ranked_edges updated
# removed edges = 120000, total edges = 147230, elasped_time = 50.60090494155884
# ranked_edges updated
# removed edges = 121000, total edges = 147230, elasped_time = 50.761090993881226
# ranked_edges updated
# removed edges = 122000, total edges = 147230, elasped_time = 49.640373945236206
# ranked_edges updated
# removed edges = 123000, total edges = 147230, elasped_time = 49.93723201751709
# ranked_edges updated
# removed edges = 124000, total edges = 147230, elasped_time = 49.18376278877258
# ranked_edges updated
# removed edges = 125000, total edges = 147230, elasped_time = 50.61500930786133
# ranked_edges updated
# removed edges = 126000, total edges = 147230, elasped_time = 49.73126029968262
# ranked_edges updated
# removed edges = 127000, total edges = 147230, elasped_time = 49.044471979141235
# ranked_edges updated
# removed edges = 128000, total edges = 147230, elasped_time = 49.85346961021423
# ranked_edges updated
# removed edges = 129000, total edges = 147230, elasped_time = 49.004992723464966
# ranked_edges updated
# removed edges = 130000, total edges = 147230, elasped_time = 49.55432057380676
# ranked_edges updated
# removed edges = 131000, total edges = 147230, elasped_time = 49.32490301132202
# ranked_edges updated
# removed edges = 132000, total edges = 147230, elasped_time = 49.314550161361694
# ranked_edges updated
# removed edges = 133000, total edges = 147230, elasped_time = 48.38782095909119
# ranked_edges updated
# removed edges = 134000, total edges = 147230, elasped_time = 48.1299102306366
# ranked_edges updated
# removed edges = 135000, total edges = 147230, elasped_time = 49.378419637680054
# ranked_edges updated
# removed edges = 136000, total edges = 147230, elasped_time = 48.38260221481323
# ranked_edges updated
# removed edges = 137000, total edges = 147230, elasped_time = 48.50302743911743
# ranked_edges updated
# removed edges = 138000, total edges = 147230, elasped_time = 49.129475355148315
# ranked_edges updated
# removed edges = 139000, total edges = 147230, elasped_time = 48.546095848083496
# ranked_edges updated
# removed edges = 140000, total edges = 147230, elasped_time = 48.04717445373535
# ranked_edges updated
# removed edges = 141000, total edges = 147230, elasped_time = 48.49477458000183
# ranked_edges updated
# removed edges = 142000, total edges = 147230, elasped_time = 48.872212409973145
# ranked_edges updated
# removed edges = 143000, total edges = 147230, elasped_time = 49.09669375419617
# ranked_edges updated
# removed edges = 144000, total edges = 147230, elasped_time = 49.72731161117554
# ranked_edges updated
# removed edges = 145000, total edges = 147230, elasped_time = 49.95450448989868
# ranked_edges updated
# removed edges = 146000, total edges = 147230, elasped_time = 49.82101774215698
# ranked_edges updated
# removed edges = 147000, total edges = 147230, elasped_time = 50.0342493057251
# ranked_edges updated

# %%
import pickle
dir = "c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/"

with open(f'{dir}removed_edges_overlap_increasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(rn, file)

with open(f'{dir}components_overlap_increasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(comps, file)

# %%
h = G.copy()
rn, comps = dismantle_edge_score(h, 'duration')
plot_dismantle(rn, comps)
# Out:
# removed edges = 0, total edges = 147230, elapsed_time = 0.0
# removed edges = 1000, total edges = 147230, elapsed_time = 46.11275029182434
# removed edges = 2000, total edges = 147230, elapsed_time = 37.30766034126282
# removed edges = 3000, total edges = 147230, elapsed_time = 36.78842043876648
# removed edges = 4000, total edges = 147230, elapsed_time = 36.086095333099365
# removed edges = 5000, total edges = 147230, elapsed_time = 38.51715087890625
# removed edges = 6000, total edges = 147230, elapsed_time = 37.26805305480957
# removed edges = 7000, total edges = 147230, elapsed_time = 36.01071119308472
# removed edges = 8000, total edges = 147230, elapsed_time = 48.656484842300415
# removed edges = 9000, total edges = 147230, elapsed_time = 45.217238426208496
# removed edges = 10000, total edges = 147230, elapsed_time = 36.443984508514404
# removed edges = 11000, total edges = 147230, elapsed_time = 37.52392768859863
# removed edges = 12000, total edges = 147230, elapsed_time = 36.03267478942871
# removed edges = 13000, total edges = 147230, elapsed_time = 36.56592082977295
# removed edges = 14000, total edges = 147230, elapsed_time = 37.065680742263794
# removed edges = 15000, total edges = 147230, elapsed_time = 36.61972784996033
# removed edges = 16000, total edges = 147230, elapsed_time = 45.8613600730896
# removed edges = 17000, total edges = 147230, elapsed_time = 44.212626218795776
# removed edges = 18000, total edges = 147230, elapsed_time = 45.93622446060181
# removed edges = 19000, total edges = 147230, elapsed_time = 43.27859091758728
# removed edges = 20000, total edges = 147230, elapsed_time = 39.32083511352539
# removed edges = 21000, total edges = 147230, elapsed_time = 37.66067314147949
# removed edges = 67000, total edges = 147230, elapsed_time = 31.49861240386963
# removed edges = 68000, total edges = 147230, elapsed_time = 31.619763374328613
# removed edges = 69000, total edges = 147230, elapsed_time = 30.7114098072052
# removed edges = 70000, total edges = 147230, elapsed_time = 32.448015213012695
# removed edges = 71000, total edges = 147230, elapsed_time = 32.01595878601074
# removed edges = 72000, total edges = 147230, elapsed_time = 30.442944765090942
# removed edges = 73000, total edges = 147230, elapsed_time = 31.27191185951233
# removed edges = 74000, total edges = 147230, elapsed_time = 31.148691177368164
# removed edges = 75000, total edges = 147230, elapsed_time = 40.9856595993042
# removed edges = 76000, total edges = 147230, elapsed_time = 55.313342571258545
# removed edges = 77000, total edges = 147230, elapsed_time = 57.434950828552246
# removed edges = 78000, total edges = 147230, elapsed_time = 54.25807189941406
# removed edges = 79000, total edges = 147230, elapsed_time = 54.95502734184265
# removed edges = 80000, total edges = 147230, elapsed_time = 54.141266107559204
# removed edges = 81000, total edges = 147230, elapsed_time = 53.31238079071045
# removed edges = 82000, total edges = 147230, elapsed_time = 52.97603893280029
# removed edges = 83000, total edges = 147230, elapsed_time = 54.193573236465454
# removed edges = 84000, total edges = 147230, elapsed_time = 55.14979839324951
# removed edges = 85000, total edges = 147230, elapsed_time = 53.303661584854126
# removed edges = 86000, total edges = 147230, elapsed_time = 52.23905110359192
# removed edges = 87000, total edges = 147230, elapsed_time = 43.29213571548462
# removed edges = 88000, total edges = 147230, elapsed_time = 51.55065679550171
# removed edges = 89000, total edges = 147230, elapsed_time = 52.14972162246704
# removed edges = 90000, total edges = 147230, elapsed_time = 47.140536308288574

# %%
import pickle
dir = "c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/"

with open(f'{dir}removed_edges_duration_decreasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(rn, file)

with open(f'{dir}components_overlap_duration_decreasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(comps, file)

# %%
h = G.copy()
rn, comps = dismantle_edge_score(h, 'duration', reverse=False)
plot_dismantle(rn, comps)
# Out:
# removed edges = 0, total edges = 147230, elapsed_time = 0.0
# removed edges = 1000, total edges = 147230, elapsed_time = 41.830973386764526
# removed edges = 2000, total edges = 147230, elapsed_time = 41.23297739028931
# removed edges = 3000, total edges = 147230, elapsed_time = 41.23042321205139
# removed edges = 4000, total edges = 147230, elapsed_time = 41.215839862823486
# removed edges = 5000, total edges = 147230, elapsed_time = 41.85780906677246
# removed edges = 6000, total edges = 147230, elapsed_time = 41.374343156814575
# removed edges = 7000, total edges = 147230, elapsed_time = 41.294310331344604
# removed edges = 8000, total edges = 147230, elapsed_time = 39.76816916465759
# removed edges = 9000, total edges = 147230, elapsed_time = 41.440099239349365
# removed edges = 10000, total edges = 147230, elapsed_time = 41.506038188934326
# removed edges = 11000, total edges = 147230, elapsed_time = 42.07404685020447
# removed edges = 12000, total edges = 147230, elapsed_time = 39.84064221382141
# removed edges = 13000, total edges = 147230, elapsed_time = 40.231889486312866
# removed edges = 14000, total edges = 147230, elapsed_time = 40.69197487831116
# removed edges = 15000, total edges = 147230, elapsed_time = 38.131786823272705
# removed edges = 16000, total edges = 147230, elapsed_time = 40.51688814163208
# removed edges = 107000, total edges = 147230, elapsed_time = 36.063427209854126
# removed edges = 108000, total edges = 147230, elapsed_time = 36.246086835861206
# removed edges = 109000, total edges = 147230, elapsed_time = 36.2897162437439
# removed edges = 110000, total edges = 147230, elapsed_time = 35.78569960594177
# removed edges = 111000, total edges = 147230, elapsed_time = 37.17985224723816
# removed edges = 112000, total edges = 147230, elapsed_time = 36.299448013305664
# removed edges = 113000, total edges = 147230, elapsed_time = 37.534756898880005
# removed edges = 114000, total edges = 147230, elapsed_time = 37.497175455093384
# removed edges = 115000, total edges = 147230, elapsed_time = 37.661606311798096
# removed edges = 116000, total edges = 147230, elapsed_time = 38.42084360122681
# removed edges = 117000, total edges = 147230, elapsed_time = 39.45634150505066
# removed edges = 118000, total edges = 147230, elapsed_time = 39.11233568191528
# removed edges = 119000, total edges = 147230, elapsed_time = 39.59583020210266
# removed edges = 120000, total edges = 147230, elapsed_time = 39.82306957244873
# removed edges = 121000, total edges = 147230, elapsed_time = 39.16704773902893
# removed edges = 122000, total edges = 147230, elapsed_time = 40.437156677246094
# removed edges = 123000, total edges = 147230, elapsed_time = 40.105876207351685
# removed edges = 124000, total edges = 147230, elapsed_time = 40.67789006233215
# removed edges = 125000, total edges = 147230, elapsed_time = 40.78841686248779
# removed edges = 126000, total edges = 147230, elapsed_time = 40.69058609008789
# removed edges = 127000, total edges = 147230, elapsed_time = 41.576252460479736
# removed edges = 128000, total edges = 147230, elapsed_time = 40.78290009498596
# removed edges = 129000, total edges = 147230, elapsed_time = 42.01729941368103
# removed edges = 130000, total edges = 147230, elapsed_time = 41.38379883766174
# removed edges = 131000, total edges = 147230, elapsed_time = 42.545631408691406
# removed edges = 132000, total edges = 147230, elapsed_time = 42.63656044006348
# removed edges = 133000, total edges = 147230, elapsed_time = 43.35054922103882
# removed edges = 134000, total edges = 147230, elapsed_time = 42.53024935722351
# removed edges = 135000, total edges = 147230, elapsed_time = 43.46579909324646
# removed edges = 136000, total edges = 147230, elapsed_time = 42.845391511917114
# removed edges = 137000, total edges = 147230, elapsed_time = 43.7961859703064
# removed edges = 138000, total edges = 147230, elapsed_time = 44.73431372642517
# removed edges = 139000, total edges = 147230, elapsed_time = 44.66230034828186
# removed edges = 140000, total edges = 147230, elapsed_time = 44.881829023361206
# removed edges = 141000, total edges = 147230, elapsed_time = 45.59445810317993
# removed edges = 142000, total edges = 147230, elapsed_time = 46.9477334022522
# removed edges = 143000, total edges = 147230, elapsed_time = 47.82944059371948
# removed edges = 144000, total edges = 147230, elapsed_time = 47.90572643280029
# removed edges = 145000, total edges = 147230, elapsed_time = 48.711522579193115
# removed edges = 146000, total edges = 147230, elapsed_time = 50.44633150100708
# removed edges = 147000, total edges = 147230, elapsed_time = 50.5341682434082

# %%
import pickle
dir = "c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/"

with open(f'{dir}removed_edges_duration_increasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(rn, file)

with open(f'{dir}components_overlap_duration_increasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(comps, file)
