# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from itertools import permutations, product
import random

# %% [markdown]
# lavorare su sample
# calcolare grandezze edge solo all'inizio o dopo tot iterazioni

# %%
# Import edges dataset.
edges = pd.read_csv("c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/edges.csv", usecols=['edge','count','source','target','source_class','target_class'])
# Import edges dataset with time indicators.
edges_complete = pd.read_csv("c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/edges_complete.csv", usecols=['date','source','target'])
# Import dataframe to link authors to their classes.
author_class = pd.read_csv("c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/author_class.csv", usecols=['author','class','i_or_e'])

# %%
authors = author_class['author'].unique()

# %%
edges_complete = edges_complete[edges_complete['source'].isin(authors) & edges_complete['target'].isin(authors)]

# %%
# Remove autoloop
edges = edges[~(edges['source'] == edges['target'])]
edges_complete = edges_complete[~(edges_complete['source'] == edges_complete['target'])]

# %%
# Create the column 'year'.
edges_complete['year'] = edges_complete['date'].apply(lambda x: x[:4])
# Keep only 2022 interactions.
edges_complete = edges_complete[edges_complete['year'].isin(['2022'])]

# %%
edges_duration = edges_complete.copy()
edges_duration['edge'] = edges_duration.apply(lambda row: {row['source'], row['target']}, axis=1)
edges_duration['edge'] = edges_duration['edge'].apply(frozenset)
edge_counts = edges_duration['edge'].value_counts()
edges_duration['count'] = edges_duration['edge'].map(edge_counts)
edges_duration['date'] = pd.to_datetime(edges_duration['date'])
duration = edges_duration.groupby('edge')['date'].agg(lambda x: x.max() - x.min())
# Map the durations back to the original DataFrame
edges_duration['duration'] = edges_duration['edge'].map(duration)

# %%
edges_duration = edges_duration.drop_duplicates('edge').drop(columns=['date'])
edges_duration['edge'] = edges_duration['edge'].apply(list)

# %%
edges_duration.sort_values('count',ascending=False)
# Out:
#                      source           target  year  \
# 437953              111god7           biwaly  2022
# 626251      Either-Fig-9343  Deep_Craft_3760  2022
# 612266     rationalistGamma      Sad_Ad_2243  2022
# 430459  astral_projections_       thatdude2_  2022
# 392884      happilypoisoned        CaveManta  2022
# ...                     ...              ...   ...
# 487654         CatMaster113        7vincent7  2022
# 487653         Flumphs_Lair        7vincent7  2022
# 487652            Le_rascal        7vincent7  2022
# 487649        exhaustedw3eb       randomistp  2022
# 645235      Deep_Craft_3760        GigiJenga  2022
#
#                                       edge  count          duration
# 437953                   [111god7, biwaly]    152   8 days 16:37:14
# 626251  [Either-Fig-9343, Deep_Craft_3760]    131   0 days 05:55:42
# 612266     [rationalistGamma, Sad_Ad_2243]    100  39 days 19:38:25
# 430459   [astral_projections_, thatdude2_]     97  26 days 14:08:48
# 392884        [happilypoisoned, CaveManta]     93 123 days 16:38:35
# ...                                    ...    ...               ...
# 487654           [7vincent7, CatMaster113]      1   0 days 00:00:00
# 487653           [7vincent7, Flumphs_Lair]      1   0 days 00:00:00
# 487652              [Le_rascal, 7vincent7]      1   0 days 00:00:00
# 487649         [randomistp, exhaustedw3eb]      1   0 days 00:00:00
# 645235        [GigiJenga, Deep_Craft_3760]      1   0 days 00:00:00
#
# [147240 rows x 6 columns]

# %%
flags = author_class.set_index('author')['i_or_e'].to_dict()

# %%
edges_duration['flag'] = edges_duration.apply(lambda row: f"{flags[row['source']]}{flags[row['target']]}", axis=1)

# %%
edges_duration.loc[edges_duration['flag'] == 'ie', 'flag'] = 'ei'

# %%
edges_duration['flag'].value_counts()
# Out:
# flag
# ii    72472
# ei    58845
# ee    15923
# Name: count, dtype: int64

# %%
nodes = list(set(edges_duration['source']) | set(edges_duration['target']))

# %%
len(nodes)
# Out:
# 14820

# %%
nodes = pd.DataFrame(nodes, columns=['author'])

# %%
nodes['flag'] = nodes['author'].apply(lambda x: flags[x])

# %%
nodes['flag'].value_counts()
# Out:
# flag
# i    10500
# e     4320
# Name: count, dtype: int64

# %%
edges_duration
# Out:
#                       source                target  year  \
# 387021           Stoopidintp  SecondaryAccount1920  2022
# 387022            artisanrox            Ne-Dom-Dev  2022
# 387023            ZeanReddit  _another_random_user  2022
# 387024  Comfortable-Banana50            hyejooxlvr  2022
# 387025          Savsquatch92              kleexxos  2022
# ...                      ...                   ...   ...
# 645228                Fawers                Zosi_O  2022
# 645230             Nebris222                K-Deni  2022
# 645232            Icy_Ad6842                K-Deni  2022
# 645233             Nebris222             GigiJenga  2022
# 645235       Deep_Craft_3760             GigiJenga  2022
#
#                                        edge  count         duration flag
# 387021  [Stoopidintp, SecondaryAccount1920]      5 38 days 18:20:54   ii
# 387022             [Ne-Dom-Dev, artisanrox]      1  0 days 00:00:00   ei
# 387023   [_another_random_user, ZeanReddit]      1  0 days 00:00:00   ii
# 387024   [hyejooxlvr, Comfortable-Banana50]      1  0 days 00:00:00   ii
# 387025             [Savsquatch92, kleexxos]      1  0 days 00:00:00   ii
# ...                                     ...    ...              ...  ...
# 645228                     [Zosi_O, Fawers]      1  0 days 00:00:00   ii
# 645230                  [Nebris222, K-Deni]      1  0 days 00:00:00   ei
# 645232                 [Icy_Ad6842, K-Deni]      1  0 days 00:00:00   ee
# 645233               [Nebris222, GigiJenga]      1  0 days 00:00:00   ei
# 645235         [GigiJenga, Deep_Craft_3760]      1  0 days 00:00:00   ei
#
# [147240 rows x 7 columns]

# %%
edges_dataframe = edges_duration.copy()
# Create the undirected weighted graph.
G = nx.Graph()
for elem, weight in zip(edges_dataframe['edge'].values.tolist(),edges_dataframe[['count', 'duration','flag']].values.tolist()):
    G.add_edge(elem[0], elem[1], weight=weight[0], duration=weight[1].seconds, flag=weight[2])

# %%
print(f'number of nodes = {G.number_of_nodes()}')
print(f'number of edges = {G.number_of_edges()}')
print(f'number of bridges = {len(list(nx.bridges(G)))}')
print(f'number of components = {nx.number_connected_components(G)}')
# Out:
# number of nodes = 14820
# number of edges = 147240
# number of bridges = 2910
# number of components = 10

# %%
# Find all connected components
components = nx.connected_components(G)

# Get the largest component
largest_component = max(components, key=len)

# Create a subgraph with the largest component
largest_subgraph = G.subgraph(largest_component).copy()

# %%
print(f'number of nodes = {largest_subgraph.number_of_nodes()}')
print(f'number of edges = {largest_subgraph.number_of_edges()}')
print(f'number of bridges = {len(list(nx.bridges(largest_subgraph)))}')
print(f'number of components = {nx.number_connected_components(largest_subgraph)}')
# Out:
# number of nodes = 14801
# number of edges = 147230
# number of bridges = 2900
# number of components = 1

# %% [markdown]
# Complete network:
# + number of nodes = 26809
# + number of edges = 367695
#
# Only 2022 network:
# + number of nodes = 14820
# + number of edges = 147240
#
# Largest connected component 2021-2022:

# %%
G = largest_subgraph.copy()

# %%
def node_overlap(g):
    for u, v in g.edges():
        n_u = set(g.neighbors(u)) # set of u neighbors
        n_v = set(g.neighbors(v)) # set of v neighbors
        overlap = len(n_u & n_v) / len(n_u | n_v) # Neighborhood Overlap
        g[u][v]['overlap'] = overlap
    return g

# %%
G = node_overlap(G)

# %%
a = list(G.edges())[2]
G[a[0]][a[1]]
# Out:
# {'weight': 3, 'duration': 51758, 'flag': 'ii', 'overlap': 0.03571428571428571}

# %%
# Compute edge betweenness centrality
#edge_betweenness = nx.edge_betweenness_centrality(G)

# %%
# for edge, centrality in edge_betweenness.items():
#     G.edges[edge]['betweenness'] = centrality

# %% [markdown]
# **RANKING**

# %%
# Create a dictionary to link authors to their classes.
author_to_class = author_class.set_index('author')['class'].to_dict()

# %%
# Rank edges by weight
ranked_edges = sorted(G.edges(data=True), key=lambda x: x[2]['weight'], reverse=True)

# Print the ranked edges
print("Edges ranked by weight:")
for rank, (u, v, attrs) in enumerate(ranked_edges, start=1):
    print(f"Rank {rank}: Edge ({u} ({author_to_class[u]}), {v} ({author_to_class[v]})) with attributes {attrs}")
    if rank == 5: break
# Out:
# Edges ranked by weight:
# Rank 1: Edge (111god7 (entp), biwaly (istj)) with attributes {'weight': 152, 'duration': 59834, 'flag': 'ei', 'overlap': 0.015360983102918587}
# Rank 2: Edge (Deep_Craft_3760 (intp), Either-Fig-9343 (entp)) with attributes {'weight': 131, 'duration': 21342, 'flag': 'ei', 'overlap': 0.015015015015015015}
# Rank 3: Edge (rationalistGamma (entj), Sad_Ad_2243 (enfp)) with attributes {'weight': 100, 'duration': 70705, 'flag': 'ee', 'overlap': 0.0912280701754386}
# Rank 4: Edge (thatdude2_ (istp), astral_projections_ (entp)) with attributes {'weight': 97, 'duration': 50928, 'flag': 'ei', 'overlap': 0.04524886877828054}
# Rank 5: Edge (happilypoisoned (istp), CaveManta (intp)) with attributes {'weight': 93, 'duration': 59915, 'flag': 'ii', 'overlap': 0.10268948655256724}

# %%
# Rank edges by node overlap
ranked_edges = sorted(G.edges(data=True), key=lambda x: x[2]['overlap'], reverse=True)

# Print the ranked edges
print("Edges ranked by node overlap:")
for rank, (u, v, attrs) in enumerate(ranked_edges, start=1):
    print(f"Rank {rank}: Edge ({u} ({author_to_class[u]}), {v} ({author_to_class[v]})) with attributes {attrs}")
    if rank == 5: break
# Out:
# Edges ranked by node overlap:
# Rank 1: Edge (Terminator_Neon (intj), onehundredirection (intj)) with attributes {'weight': 1, 'duration': 0, 'flag': 'ii', 'overlap': 0.25}
# Rank 2: Edge (space_ace33 (isfj), katiurna (intj)) with attributes {'weight': 2, 'duration': 1969, 'flag': 'ii', 'overlap': 0.25}
# Rank 3: Edge (TheSneakyHider (intp), SetSailToTheStreets (isfp)) with attributes {'weight': 2, 'duration': 59305, 'flag': 'ii', 'overlap': 0.25}
# Rank 4: Edge (criminallygorgeous (entp), xxreyna (entj)) with attributes {'weight': 2, 'duration': 2214, 'flag': 'ee', 'overlap': 0.23076923076923078}
# Rank 5: Edge (garrafinhael (isfp), 0x51N4 (entp)) with attributes {'weight': 1, 'duration': 0, 'flag': 'ei', 'overlap': 0.2222222222222222}

# %%
# # Rank edges by betweenness centrality
# ranked_edges = sorted(G.edges(data=True), key=lambda x: x[2]['betweenness'], reverse=True)

# # Print the ranked edges
# print("Edges ranked by betweenness centrality:")
# for rank, (u, v, attrs) in enumerate(ranked_edges, start=1):
#     print(f"Rank {rank}: Edge ({u} ({author_to_class[u]}), {v} ({author_to_class[v]})) with attributes {attrs}")
#     if rank == 5: break

# %%
# Rank edges by interaction duration
ranked_edges = sorted(G.edges(data=True), key=lambda x: x[2]['duration'], reverse=True)

# Print the ranked edges
print("Edges ranked by interaction duration:")
for rank, (u, v, attrs) in enumerate(ranked_edges, start=1):
    print(f"Rank {rank}: Edge ({u} ({author_to_class[u]}), {v} ({author_to_class[v]})) with attributes {attrs}")
    if rank == 5: break
# Out:
# Edges ranked by interaction duration:
# Rank 1: Edge (ChocolateCakeReturns (intj), Player20310 (infp)) with attributes {'weight': 3, 'duration': 86399, 'flag': 'ii', 'overlap': 0.03289473684210526}
# Rank 2: Edge (sapphire-lily (infp), Helpful-Floor-9568 (intp)) with attributes {'weight': 3, 'duration': 86396, 'flag': 'ii', 'overlap': 0.014336917562724014}
# Rank 3: Edge (coffee9000000 (entp), anon3896081 (entj)) with attributes {'weight': 4, 'duration': 86396, 'flag': 'ee', 'overlap': 0.0035335689045936395}
# Rank 4: Edge (Lover_of_YOU (infp), melody5697 (infp)) with attributes {'weight': 3, 'duration': 86393, 'flag': 'ii', 'overlap': 0.007731958762886598}
# Rank 5: Edge (Deep_Craft_3760 (intp), smayley (istp)) with attributes {'weight': 4, 'duration': 86388, 'flag': 'ii', 'overlap': 0.01812688821752266}

# %% [markdown]
# **e-e**, **i-e**, **i-i**

# %%
# Rank edges by weight
ranked_edges = sorted(G.edges(data=True), key=lambda x: x[2]['weight'], reverse=True)
ranked_edges = G.edges(data=True)

# %%
e_e = []
i_i = []
e_i = []

for u,v,attrs in ranked_edges:
    if (author_to_class[u][0] == 'e' and author_to_class[v][0] == 'e'): e_e.append(attrs['weight'])
    elif (author_to_class[u][0] == 'i' and author_to_class[v][0] == 'i'): i_i.append(attrs['weight']) 
    else: e_i.append(attrs['weight'])

# %%
print(f'e_e mean = {np.mean(e_e)}')
print(f'e_i mean = {np.mean(e_i)}')
print(f'i_i mean = {np.mean(i_i)}')
# Out:
# e_e mean = 1.7815110217923757
# e_i mean = 1.7346737597090267
# i_i mean = 1.674348006071478

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,3,1)
plt.hist(e_e,bins=50, color='blue')
plt.yscale('log')
plt.subplot(1,3,2)
plt.hist(i_i,bins=50, color='red')
plt.yscale('log')
plt.subplot(1,3,3)
plt.hist(e_i,bins=50, color='green')
plt.yscale('log')

# %%
e_e = []
i_i = []
e_i = []

attr = 'duration'
for u,v,attrs in ranked_edges:
    if (author_to_class[u][0] == 'e' and author_to_class[v][0] == 'e'): e_e.append(attrs[attr])
    elif (author_to_class[u][0] == 'i' and author_to_class[v][0] == 'i'): i_i.append(attrs[attr]) 
    else: e_i.append(attrs[attr])

# %%
print(f'e_e mean = {np.mean(e_e)}')
print(f'e_i mean = {np.mean(e_i)}')
print(f'i_i mean = {np.mean(i_i)}')
# Out:
# e_e mean = 6316.320040193431
# e_i mean = 5990.364396553189
# i_i mean = 5777.0081550986615

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,3,1)
plt.hist(e_e,bins=50, color='blue')
plt.yscale('log')
plt.subplot(1,3,2)
plt.hist(i_i,bins=50, color='red')
plt.yscale('log')
plt.subplot(1,3,3)
plt.hist(e_i,bins=50, color='green')
plt.yscale('log')

# %%
e_e = []
i_i = []
e_i = []

attr = 'overlap'
for u,v,attrs in ranked_edges:
    if (author_to_class[u][0] == 'e' and author_to_class[v][0] == 'e'): e_e.append(attrs[attr])
    elif (author_to_class[u][0] == 'i' and author_to_class[v][0] == 'i'): i_i.append(attrs[attr]) 
    else: e_i.append(attrs[attr])

# %%
print(f'e_e mean = {np.mean(e_e)}')
print(f'e_i mean = {np.mean(e_i)}')
print(f'i_i mean = {np.mean(i_i)}')
# Out:
# e_e mean = 0.02139449110472029
# e_i mean = 0.02161510704304966
# i_i mean = 0.020839523708189034

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,3,1)
plt.hist(e_e,bins=50, color='blue')
plt.yscale('log')
plt.subplot(1,3,2)
plt.hist(i_i,bins=50, color='red')
plt.yscale('log')
plt.subplot(1,3,3)
plt.hist(e_i,bins=50, color='green')
plt.yscale('log')

# %%
ranked_edges = G.edges(data=True)
e_e = []
i_i = []
e_i = []

for u,v,attrs in ranked_edges:
    if (author_to_class[u][0] == 'e' and author_to_class[v][0] == 'e'): e_e.append([attrs['weight'], attrs['overlap'], attrs['duration']])
    elif (author_to_class[u][0] == 'i' and author_to_class[v][0] == 'i'): i_i.append([attrs['weight'], attrs['overlap'], attrs['duration']]) 
    else: e_i.append([attrs['weight'], attrs['overlap'], attrs['duration']])

e_e = np.array(e_e)
e_i = np.array(e_i)
i_i = np.array(i_i)

# %%
xlabel = ['Weight', 'Node Overlap', 'Duration']
title = ['e_e links', 'e_i links', 'i_i links']
plt.figure(figsize=(15,8))
for i in range(3):
    plt.subplot(3,3,3*i+1)
    if i == 0: plt.title(title[0])
    plt.hist(e_e[:,i], bins=50, color='blue')
    plt.ylabel('Number of edges')
    if i == 2: plt.xlabel(xlabel[i])
    plt.yscale('log')

    plt.subplot(3,3,3*i+2)
    if i == 0: plt.title(title[1])
    plt.hist(e_i[:,i], bins=50, color='green')
    plt.ylabel('Number of edges')
    if i == 2: plt.xlabel(xlabel[i])
    plt.yscale('log')

    plt.subplot(3,3,3*i+3)
    if i == 0: plt.title(title[2])
    plt.hist(i_i[:,i], bins=50, color='red')
    plt.ylabel('Number of edges')
    if i == 2: plt.xlabel(xlabel[i])
    plt.yscale('log')

# %%
xlabel = ['Weight', 'Node Overlap', 'Duration']
title = ['Weight', 'Node Overlap', 'Duration']
plt.figure(figsize=(15,8))
for i in range(3):
    plt.subplot(3,3,i+1)
    #plt.title(title[i])
    if i == 0: plt.hist(e_e[:,i], bins=50, color='blue', label='e_e edges')
    else: plt.hist(e_e[:,i], bins=50, color='blue')
    plt.axvline(x=np.mean(e_e[:,i]), color='k', linestyle='--', linewidth=1, label=f'mean = {round(np.mean(e_e[:,i]),3)}')
    if i == 0: plt.ylabel('Number of edges')
    plt.yscale('log')
    plt.legend(loc='best')

    plt.subplot(3,3,i+4)
    
    if i == 0: plt.hist(e_i[:,i], bins=50, color='green', label='e_i edges')
    else: plt.hist(e_i[:,i], bins=50, color='green')
    plt.axvline(x=np.mean(e_i[:,i]), color='k', linestyle='--', linewidth=1, label=f'mean = {round(np.mean(e_i[:,i]),3)}')
    if i == 0: plt.ylabel('Number of edges')
    plt.yscale('log')
    plt.legend(loc='best')

    plt.subplot(3,3,i+7)
    if i == 0: plt.hist(i_i[:,i], bins=50, color='red', label='i_i edges')
    else: plt.hist(i_i[:,i], bins=50, color='red')
    plt.axvline(x=np.mean(i_i[:,i]), color='k', linestyle='--', linewidth=1, label=f'mean = {round(np.mean(i_i[:,i]),3)}')
    #plt.text(x=np.mean(i_i[:,i])+np.mean(i_i[:,i])/5,y=np.histogram(i_i[:,i])[0][0], s=f'mean = {np.mean(i_i[:,i])}')
    if i == 0: plt.ylabel('Number of edges')
    plt.xlabel(xlabel[i])
    plt.legend(loc='best')
    plt.yscale('log')

# %% [markdown]
# We can see that the distributions and their mean values are similiar for each type of interaction (e_e, e_i and i_i), in general.
# As expected removing edges with low node overlap (local bridges) first destroy the network faster
# As anticipated, the initial removal of edges characterized by low node overlap (i.e., local bridges) leads to a more rapid disintegration of the network structure.

# %% [markdown]
# Fare correlazione tra node overlap, weight e duration.

# %%
a = list(G.edges())[2]
G[a[0]][a[1]]
# Out:
# {'weight': 3, 'duration': 51758, 'flag': 'ii', 'overlap': 0.03571428571428571}

# %%
data = []
for u, v, attrs in G.edges(data=True):
    data.append([attrs['weight'], attrs['overlap'], attrs['duration']])
    
df = pd.DataFrame(data, columns=['weight', 'overlap', 'duration'])

correlation_matrix = df.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Edge Attributes')
plt.show()

# %%
e_e = []
e_i = []
i_i = []
for u,v,attrs in ranked_edges:
    if (author_to_class[u][0] == 'e' and author_to_class[v][0] == 'e'): e_e.append([attrs['weight'], attrs['overlap'], attrs['duration']])
    elif (author_to_class[u][0] == 'i' and author_to_class[v][0] == 'i'): i_i.append([attrs['weight'], attrs['overlap'], attrs['duration']]) 
    else: e_i.append([attrs['weight'], attrs['overlap'], attrs['duration']])

# %%
for data in [e_e, e_i, i_i]:

    df = pd.DataFrame(data, columns=['weight', 'overlap', 'duration'])

    correlation_matrix = df.corr()

    # Plot the correlation matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
    plt.title('Correlation Matrix of Edge Attributes')
    plt.show()

# %% [markdown]
# **NETWORK RESILIANCE**

# %%
import time

def random_edge(g): # select a random node from graph
    return random.choice(list(g.edges()))

def best_score_edge(g, score):
    tmp = sorted(g.edges(data=True), key=lambda x: x[2][score], reverse=True)
    return (tmp[0][0], tmp[0][1])

def dismantle_edge(g, function, **args): # incrementally removes edges from a graph and computes size of connected components
    total_edges = g.number_of_edges()
    removed_edges = []
    components = []
    while g.number_of_edges() > 1:
        if g.number_of_edges() % 1000 == 0: print(f'edges = {g.number_of_edges()}, total edges = {total_edges}')
        t00 = time.time()
        e = function(g, **args)
        #print(f'Elapsed time function = {time.time()-t00}')
        #t0 = time.time()
        g.remove_edge(*e)
        #print(f'Elapsed time edge removal = {time.time()-t0}')

        removed_edges.append((len(removed_edges)+1)/total_edges)
        #t0 = time.time()
        comps = list(nx.connected_components(g))
        #print(f'Elapsed time connected_components = {time.time()-t0}')
        g_size = 0
        # if len(comps)>0:
        g_size  = max([len(c)for c in comps])/total_edges
        components.append(g_size)
        print(f'Elapsed time = {time.time()-t00}')
    return removed_edges, components


def dismantle_edge_overlap(g, repeat_rank = 1000, reverse=True): # incrementally removes edges from a graph and computes size of connected components
    total_edges = g.number_of_edges()
    removed_edges = []
    components = []
    g = node_overlap(g)
    ranked_edges = sorted(g.edges(data=True), key=lambda x: x[2]['overlap'], reverse=reverse)
    i = 0
    t0 = time.time()
    while i < (total_edges):
        if i % 1000 == 0:
            print(f'removed edges = {i}, total edges = {total_edges}, elasped_time = {time.time()-t0}')
            t0 = time.time()
        #t00 = time.time()
        if i % repeat_rank == 0:
            g = node_overlap(g)
            ranked_edges = sorted(g.edges(data=True), key=lambda x: x[2]['overlap'], reverse=reverse)
            print(f'ranked_edges updated')

        e = ranked_edges.pop(0)
        #print(f'Elapsed time function = {time.time()-t00}')
        #t0 = time.time()
        g.remove_edge(e[0],e[1])
        #print(f'Elapsed time edge removal = {time.time()-t0}')
        i += 1
        removed_edges.append(i/total_edges)
        #t0 = time.time()
        comps = list(nx.connected_components(g))
        #print(f'Elapsed time connected_components = {time.time()-t0}')
        g_size = 0
        # if len(comps)>0:
        g_size  = max([len(c)for c in comps])/total_edges
        components.append(g_size)
        #print(f'Elapsed time = {time.time()-t00}')
    return removed_edges, components

def dismantle_edge_score(g, score, reverse=True): # incrementally removes edges from a graph and computes size of connected components
    total_edges = g.number_of_edges()
    removed_edges = []
    components = []
    ranked_edges = sorted(g.edges(data=True), key=lambda x: x[2][score], reverse=reverse)
    i = 0
    t0 = time.time()
    while i < (total_edges):
        if i % 1000 == 0:
            print(f'removed edges = {i}, total edges = {total_edges}, elapsed_time = {time.time()-t0}')
            t0 = time.time()
        #t00 = time.time()
        e = ranked_edges.pop(0)
        #print(f'Elapsed time function = {time.time()-t00}')
        #t0 = time.time()
        g.remove_edge(e[0],e[1])
        #print(f'Elapsed time edge removal = {time.time()-t0}')
        i += 1
        removed_edges.append(i/total_edges)
        #t0 = time.time()
        comps = list(nx.connected_components(g))
        #print(f'Elapsed time connected_components = {time.time()-t0}')
        g_size = 0
        # if len(comps)>0:
        g_size  = max([len(c)for c in comps])/total_edges
        components.append(g_size)
        #print(f'Elapsed time = {time.time()-t00}')
    return removed_edges, components

def dismantle_edge_random(g): # incrementally removes edges from a graph and computes size of connected components
    total_edges = g.number_of_edges()
    removed_edges = []
    components = []
    i = 0
    t0 = time.time()
    random_list = list(g.edges())
    random.shuffle(random_list)
    while i < (total_edges):
        if i % 1000 == 0:
            print(f'removed edges = {i}, total edges = {total_edges}, elapsed_time = {time.time()-t0}')
            t0 = time.time()
        #t00 = time.time()
        e = random_list.pop(0)
        #print(f'Elapsed time function = {time.time()-t00}')
        #t0 = time.time()
        g.remove_edge(e[0],e[1])
        #print(f'Elapsed time edge removal = {time.time()-t0}')
        i += 1
        removed_edges.append(i/total_edges)
        #t0 = time.time()
        comps = list(nx.connected_components(g))
        #print(f'Elapsed time connected_components = {time.time()-t0}')
        g_size = 0
        # if len(comps)>0:
        g_size  = max([len(c)for c in comps])/total_edges
        components.append(g_size)
        #print(f'Elapsed time = {time.time()-t00}')
    return removed_edges, components

def plot_dismantle(x, y):
    plt.figure(figsize=(15,8))
    plt.plot(x, y)
    plt.xlabel("Removed Edges")
    plt.ylabel("Giant Component size")
    plt.show()

# %%
label_counts = {'ee': 0, 'ii': 0, 'ei': 0}
for _, _, data in G.edges(data=True):
    label = data.get('flag')
    if label in label_counts:
        label_counts[label] += 1

# %%
label_counts
# Out:
# {'ee': 15923, 'ii': 72470, 'ei': 58837}

# %%
def dismantle_edge_overlap_2(g, repeat_rank = 1000, reverse=True): # incrementally removes edges from a graph and computes size of connected components
    total_edges = g.number_of_edges()
    label_counts = {'ee': 0, 'ii': 0, 'ei': 0}
    for _, _, data in G.edges(data=True):
        label = data.get('flag')
        if label in label_counts:
            label_counts[label] += 1
    edge_fraction = {'ee': [label_counts['ee']], 'ii': [label_counts['ii']], 'ei': [label_counts['ei']]}
    
    g = node_overlap(g)
    ranked_edges = sorted(g.edges(data=True), key=lambda x: x[2]['overlap'], reverse=reverse)
    i = 0
    t0 = time.time()
    while i < (total_edges):
        if i % 1000 == 0:
            print(f'removed edges = {i}, total edges = {total_edges}, elasped_time = {time.time()-t0}')
            t0 = time.time()
        #t00 = time.time()
        if i % repeat_rank == 0:
            g = node_overlap(g)
            ranked_edges = sorted(g.edges(data=True), key=lambda x: x[2]['overlap'], reverse=reverse)
            print(f'ranked_edges updated')

        e = ranked_edges.pop(0)
        #print(f'Elapsed time function = {time.time()-t00}')
        #t0 = time.time()
        fl = e[2]['flag']
        g.remove_edge(e[0],e[1])
        for key in edge_fraction.keys():
            if key == fl:
                edge_fraction[key].append(edge_fraction[key][-1]-1)
            else: edge_fraction[key].append(edge_fraction[key][-1])
        #print(f'Elapsed time edge removal = {time.time()-t0}')
        i += 1
        #t0 = time.time()
        #print(f'Elapsed time = {time.time()-t00}')
    return edge_fraction

def dismantle_edge_random_2(g): # incrementally removes edges from a graph and computes size of connected components
    total_edges = g.number_of_edges()
    label_counts = {'ee': 0, 'ii': 0, 'ei': 0}
    for _, _, data in G.edges(data=True):
        label = data.get('flag')
        if label in label_counts:
            label_counts[label] += 1
    edge_fraction = {'ee': [label_counts['ee']], 'ii': [label_counts['ii']], 'ei': [label_counts['ei']]}
    
    random_list = list(g.edges(data=True))
    random.shuffle(random_list)
    i = 0
    t0 = time.time()
    while i < (total_edges):
        if i % 1000 == 0:
            print(f'removed edges = {i}, total edges = {total_edges}, elasped_time = {time.time()-t0}')
            t0 = time.time()
        #t00 = time.time()

        e = random_list.pop(0)
        #print(f'Elapsed time function = {time.time()-t00}')
        #t0 = time.time()
        fl = e[2]['flag']
        g.remove_edge(e[0],e[1])
        for key in edge_fraction.keys():
            if key == fl:
                edge_fraction[key].append(edge_fraction[key][-1]-1)
            else: edge_fraction[key].append(edge_fraction[key][-1])
        #print(f'Elapsed time edge removal = {time.time()-t0}')
        i += 1
        #t0 = time.time()
        #print(f'Elapsed time = {time.time()-t00}')
    return edge_fraction

# %%
h = G.copy()
rn = dismantle_edge_random_2(h)
#plot_dismantle(rn, comps)
# Out:
# removed edges = 0, total edges = 147230, elasped_time = 0.0
# removed edges = 1000, total edges = 147230, elasped_time = 0.05055713653564453
# removed edges = 2000, total edges = 147230, elasped_time = 0.04427289962768555
# removed edges = 3000, total edges = 147230, elasped_time = 0.03848719596862793
# removed edges = 4000, total edges = 147230, elasped_time = 0.03336215019226074
# removed edges = 5000, total edges = 147230, elasped_time = 0.040816307067871094
# removed edges = 6000, total edges = 147230, elasped_time = 0.03505229949951172
# removed edges = 7000, total edges = 147230, elasped_time = 0.041275978088378906
# removed edges = 8000, total edges = 147230, elasped_time = 0.035057783126831055
# removed edges = 9000, total edges = 147230, elasped_time = 0.03944540023803711
# removed edges = 10000, total edges = 147230, elasped_time = 0.03640341758728027
# removed edges = 11000, total edges = 147230, elasped_time = 0.03836560249328613
# removed edges = 12000, total edges = 147230, elasped_time = 0.03324127197265625
# removed edges = 13000, total edges = 147230, elasped_time = 0.03325176239013672
# removed edges = 14000, total edges = 147230, elasped_time = 0.04246187210083008
# removed edges = 15000, total edges = 147230, elasped_time = 0.03920936584472656
# removed edges = 16000, total edges = 147230, elasped_time = 0.03965258598327637
# removed edges = 17000, total edges = 147230, elasped_time = 0.028626203536987305
# removed edges = 18000, total edges = 147230, elasped_time = 0.04069781303405762
# removed edges = 19000, total edges = 147230, elasped_time = 0.03493332862854004
# removed edges = 20000, total edges = 147230, elasped_time = 0.034421682357788086
# removed edges = 21000, total edges = 147230, elasped_time = 0.03978133201599121
# removed edges = 22000, total edges = 147230, elasped_time = 0.03455996513366699
# removed edges = 23000, total edges = 147230, elasped_time = 0.029999971389770508
# removed edges = 24000, total edges = 147230, elasped_time = 0.030030250549316406
# removed edges = 25000, total edges = 147230, elasped_time = 0.029666900634765625
# removed edges = 26000, total edges = 147230, elasped_time = 0.036615610122680664
# removed edges = 27000, total edges = 147230, elasped_time = 0.03166556358337402
# removed edges = 118000, total edges = 147230, elasped_time = 0.017990589141845703
# removed edges = 119000, total edges = 147230, elasped_time = 0.0034542083740234375
# removed edges = 120000, total edges = 147230, elasped_time = 0.009787559509277344
# removed edges = 121000, total edges = 147230, elasped_time = 0.008543014526367188
# removed edges = 122000, total edges = 147230, elasped_time = 0.010407686233520508
# removed edges = 123000, total edges = 147230, elasped_time = 0.007852315902709961
# removed edges = 124000, total edges = 147230, elasped_time = 0.008305788040161133
# removed edges = 125000, total edges = 147230, elasped_time = 0.003231525421142578
# removed edges = 126000, total edges = 147230, elasped_time = 0.00959014892578125
# removed edges = 127000, total edges = 147230, elasped_time = 0.0025119781494140625
# removed edges = 128000, total edges = 147230, elasped_time = 0.00750732421875
# removed edges = 129000, total edges = 147230, elasped_time = 0.010012626647949219
# removed edges = 130000, total edges = 147230, elasped_time = 0.0
# removed edges = 131000, total edges = 147230, elasped_time = 0.009997367858886719
# removed edges = 132000, total edges = 147230, elasped_time = 0.0
# removed edges = 133000, total edges = 147230, elasped_time = 0.00999903678894043
# removed edges = 134000, total edges = 147230, elasped_time = 0.009007930755615234
# removed edges = 135000, total edges = 147230, elasped_time = 0.005362033843994141
# removed edges = 136000, total edges = 147230, elasped_time = 0.0034646987915039062
# removed edges = 137000, total edges = 147230, elasped_time = 0.0
# removed edges = 138000, total edges = 147230, elasped_time = 0.00850820541381836
# removed edges = 139000, total edges = 147230, elasped_time = 0.0027980804443359375
# removed edges = 140000, total edges = 147230, elasped_time = 0.0
# removed edges = 141000, total edges = 147230, elasped_time = 0.0075452327728271484
# removed edges = 142000, total edges = 147230, elasped_time = 0.0
# removed edges = 143000, total edges = 147230, elasped_time = 0.010292768478393555
# removed edges = 144000, total edges = 147230, elasped_time = 0.0
# removed edges = 145000, total edges = 147230, elasped_time = 0.0
# removed edges = 146000, total edges = 147230, elasped_time = 0.011103153228759766
# removed edges = 147000, total edges = 147230, elasped_time = 0.0022728443145751953

# %%
import pickle
dir = "c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/"

with open(f'{dir}removed_edges_random.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(rn, file)

with open(f'{dir}components_random.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(comps, file)

# %%
h = G.copy()
rn, comps = dismantle_edge_overlap(h, repeat_rank = 1000, reverse= True)
plot_dismantle(rn, comps)
# Out:
# removed edges = 0, total edges = 147230, elasped_time = 0.0
# ranked_edges updated
# removed edges = 1000, total edges = 147230, elasped_time = 45.87699294090271
# ranked_edges updated
# removed edges = 2000, total edges = 147230, elasped_time = 46.38887548446655
# ranked_edges updated
# removed edges = 3000, total edges = 147230, elasped_time = 46.03261923789978
# ranked_edges updated
# removed edges = 4000, total edges = 147230, elasped_time = 66.65208649635315
# ranked_edges updated
# removed edges = 5000, total edges = 147230, elasped_time = 88.59942579269409
# ranked_edges updated
# removed edges = 6000, total edges = 147230, elasped_time = 86.87066984176636
# ranked_edges updated
# removed edges = 7000, total edges = 147230, elasped_time = 85.61857867240906
# ranked_edges updated
# removed edges = 8000, total edges = 147230, elasped_time = 86.55860447883606
# ranked_edges updated
# removed edges = 9000, total edges = 147230, elasped_time = 85.69751501083374
# ranked_edges updated
# removed edges = 10000, total edges = 147230, elasped_time = 82.84055757522583
# ranked_edges updated
# removed edges = 11000, total edges = 147230, elasped_time = 92.64135837554932
# ranked_edges updated
# removed edges = 12000, total edges = 147230, elasped_time = 79.28734064102173
# ranked_edges updated
# removed edges = 13000, total edges = 147230, elasped_time = 71.12453818321228
# ranked_edges updated
# removed edges = 14000, total edges = 147230, elasped_time = 72.70348906517029
# ranked_edges updated
# removed edges = 15000, total edges = 147230, elasped_time = 69.46525287628174
# ranked_edges updated
# removed edges = 16000, total edges = 147230, elasped_time = 70.24576091766357
# ranked_edges updated
# removed edges = 17000, total edges = 147230, elasped_time = 70.44869303703308
# ranked_edges updated
# removed edges = 18000, total edges = 147230, elasped_time = 63.59065628051758
# ranked_edges updated
# removed edges = 19000, total edges = 147230, elasped_time = 42.49332118034363
# ranked_edges updated
# removed edges = 20000, total edges = 147230, elasped_time = 44.08637976646423
# ranked_edges updated
# removed edges = 21000, total edges = 147230, elasped_time = 42.18969774246216
# ranked_edges updated
# removed edges = 22000, total edges = 147230, elasped_time = 41.64993238449097
# ranked_edges updated
# removed edges = 23000, total edges = 147230, elasped_time = 59.02471876144409
# ranked_edges updated
# removed edges = 24000, total edges = 147230, elasped_time = 82.63515400886536
# ranked_edges updated
# removed edges = 25000, total edges = 147230, elasped_time = 78.05202102661133
# ranked_edges updated
# removed edges = 26000, total edges = 147230, elasped_time = 56.99824500083923
# ranked_edges updated
# removed edges = 27000, total edges = 147230, elasped_time = 52.95359492301941
# ranked_edges updated
# removed edges = 28000, total edges = 147230, elasped_time = 50.36328864097595
# ranked_edges updated
# removed edges = 29000, total edges = 147230, elasped_time = 44.51128792762756
# ranked_edges updated
# removed edges = 30000, total edges = 147230, elasped_time = 37.802515268325806
# ranked_edges updated
# removed edges = 31000, total edges = 147230, elasped_time = 38.55272197723389
# ranked_edges updated
# removed edges = 32000, total edges = 147230, elasped_time = 36.29694700241089
# ranked_edges updated
# removed edges = 33000, total edges = 147230, elasped_time = 40.870014667510986
# ranked_edges updated
# removed edges = 34000, total edges = 147230, elasped_time = 39.591795444488525
# ranked_edges updated
# removed edges = 35000, total edges = 147230, elasped_time = 37.78350901603699
# ranked_edges updated
# removed edges = 36000, total edges = 147230, elasped_time = 38.39065623283386
# ranked_edges updated
# removed edges = 37000, total edges = 147230, elasped_time = 36.5625376701355
# ranked_edges updated
# removed edges = 38000, total edges = 147230, elasped_time = 37.394933223724365
# ranked_edges updated
# removed edges = 39000, total edges = 147230, elasped_time = 38.58699107170105
# ranked_edges updated
# removed edges = 40000, total edges = 147230, elasped_time = 35.7147171497345
# ranked_edges updated
# removed edges = 41000, total edges = 147230, elasped_time = 34.5555853843689
# ranked_edges updated
# removed edges = 42000, total edges = 147230, elasped_time = 35.690430641174316
# ranked_edges updated
# removed edges = 43000, total edges = 147230, elasped_time = 39.39792799949646
# ranked_edges updated
# removed edges = 44000, total edges = 147230, elasped_time = 45.96039700508118
# ranked_edges updated
# removed edges = 45000, total edges = 147230, elasped_time = 44.464152336120605
# ranked_edges updated
# removed edges = 46000, total edges = 147230, elasped_time = 51.81868243217468
# ranked_edges updated
# removed edges = 47000, total edges = 147230, elasped_time = 47.002798080444336
# ranked_edges updated
# removed edges = 48000, total edges = 147230, elasped_time = 46.465927839279175
# ranked_edges updated
# removed edges = 49000, total edges = 147230, elasped_time = 45.886215925216675
# ranked_edges updated
# removed edges = 50000, total edges = 147230, elasped_time = 45.69960570335388
# ranked_edges updated
# removed edges = 51000, total edges = 147230, elasped_time = 44.975600719451904
# ranked_edges updated
# removed edges = 52000, total edges = 147230, elasped_time = 37.18593096733093
# ranked_edges updated
# removed edges = 53000, total edges = 147230, elasped_time = 35.62981629371643
# ranked_edges updated
# removed edges = 54000, total edges = 147230, elasped_time = 35.56295418739319
# ranked_edges updated
# removed edges = 55000, total edges = 147230, elasped_time = 36.569796085357666
# ranked_edges updated
# removed edges = 56000, total edges = 147230, elasped_time = 36.111215114593506
# ranked_edges updated
# removed edges = 57000, total edges = 147230, elasped_time = 36.34132146835327
# ranked_edges updated
# removed edges = 58000, total edges = 147230, elasped_time = 32.20294761657715
# ranked_edges updated
# removed edges = 59000, total edges = 147230, elasped_time = 34.47448945045471
# ranked_edges updated
# removed edges = 60000, total edges = 147230, elasped_time = 35.52104735374451
# ranked_edges updated
# removed edges = 61000, total edges = 147230, elasped_time = 32.71927070617676
# ranked_edges updated
# removed edges = 62000, total edges = 147230, elasped_time = 32.738993406295776
# ranked_edges updated
# removed edges = 63000, total edges = 147230, elasped_time = 32.96731352806091
# ranked_edges updated
# removed edges = 64000, total edges = 147230, elasped_time = 34.07817578315735
# ranked_edges updated
# removed edges = 65000, total edges = 147230, elasped_time = 31.911420822143555
# ranked_edges updated
# removed edges = 66000, total edges = 147230, elasped_time = 32.755110025405884
# ranked_edges updated
# removed edges = 67000, total edges = 147230, elasped_time = 33.572012186050415
# ranked_edges updated
# removed edges = 68000, total edges = 147230, elasped_time = 31.743632793426514
# ranked_edges updated
# removed edges = 69000, total edges = 147230, elasped_time = 32.89208769798279
# ranked_edges updated
# removed edges = 70000, total edges = 147230, elasped_time = 30.390431880950928
# ranked_edges updated
# removed edges = 71000, total edges = 147230, elasped_time = 32.59663987159729
# ranked_edges updated
# removed edges = 72000, total edges = 147230, elasped_time = 31.1973614692688
# ranked_edges updated
# removed edges = 73000, total edges = 147230, elasped_time = 33.812514781951904
# ranked_edges updated
# removed edges = 74000, total edges = 147230, elasped_time = 43.544203996658325
# ranked_edges updated
# removed edges = 75000, total edges = 147230, elasped_time = 31.20384955406189
# ranked_edges updated
# removed edges = 76000, total edges = 147230, elasped_time = 30.627399921417236
# ranked_edges updated
# removed edges = 77000, total edges = 147230, elasped_time = 30.752787590026855
# ranked_edges updated
# removed edges = 78000, total edges = 147230, elasped_time = 29.86821460723877
# ranked_edges updated
# removed edges = 79000, total edges = 147230, elasped_time = 31.522557258605957
# ranked_edges updated
# removed edges = 80000, total edges = 147230, elasped_time = 28.69934105873108
# ranked_edges updated
# removed edges = 81000, total edges = 147230, elasped_time = 28.795108795166016
# ranked_edges updated
# removed edges = 82000, total edges = 147230, elasped_time = 29.48858141899109
# ranked_edges updated
# removed edges = 83000, total edges = 147230, elasped_time = 29.292766332626343
# ranked_edges updated
# removed edges = 84000, total edges = 147230, elasped_time = 29.357577800750732
# ranked_edges updated
# removed edges = 85000, total edges = 147230, elasped_time = 28.675132513046265
# ranked_edges updated
# removed edges = 86000, total edges = 147230, elasped_time = 28.925137281417847
# ranked_edges updated
# removed edges = 87000, total edges = 147230, elasped_time = 28.990071296691895
# ranked_edges updated
# removed edges = 88000, total edges = 147230, elasped_time = 29.785862922668457
# ranked_edges updated
# removed edges = 89000, total edges = 147230, elasped_time = 30.35972023010254
# ranked_edges updated
# removed edges = 90000, total edges = 147230, elasped_time = 29.079439401626587
# ranked_edges updated
# removed edges = 91000, total edges = 147230, elasped_time = 30.696460485458374
# ranked_edges updated
# removed edges = 92000, total edges = 147230, elasped_time = 29.06031823158264
# ranked_edges updated
# removed edges = 93000, total edges = 147230, elasped_time = 30.035725831985474
# ranked_edges updated
# removed edges = 94000, total edges = 147230, elasped_time = 29.852637767791748
# ranked_edges updated
# removed edges = 95000, total edges = 147230, elasped_time = 30.695943117141724
# ranked_edges updated
# removed edges = 96000, total edges = 147230, elasped_time = 30.23503303527832
# ranked_edges updated
# removed edges = 97000, total edges = 147230, elasped_time = 29.376405477523804
# ranked_edges updated
# removed edges = 98000, total edges = 147230, elasped_time = 30.000123739242554
# ranked_edges updated
# removed edges = 99000, total edges = 147230, elasped_time = 31.11633825302124
# ranked_edges updated
# removed edges = 100000, total edges = 147230, elasped_time = 32.93201780319214
# ranked_edges updated
# removed edges = 101000, total edges = 147230, elasped_time = 31.563939809799194
# ranked_edges updated
# removed edges = 102000, total edges = 147230, elasped_time = 32.089253664016724
# ranked_edges updated
# removed edges = 103000, total edges = 147230, elasped_time = 31.523194551467896
# ranked_edges updated
# removed edges = 104000, total edges = 147230, elasped_time = 32.54683971405029
# ranked_edges updated
# removed edges = 105000, total edges = 147230, elasped_time = 33.52731943130493
# ranked_edges updated
# removed edges = 106000, total edges = 147230, elasped_time = 32.5296049118042
# ranked_edges updated
# removed edges = 107000, total edges = 147230, elasped_time = 33.46891260147095
# ranked_edges updated
# removed edges = 108000, total edges = 147230, elasped_time = 34.55348873138428
# ranked_edges updated
# removed edges = 109000, total edges = 147230, elasped_time = 33.86874198913574
# ranked_edges updated
# removed edges = 110000, total edges = 147230, elasped_time = 34.753732204437256
# ranked_edges updated
# removed edges = 111000, total edges = 147230, elasped_time = 35.205349922180176
# ranked_edges updated
# removed edges = 112000, total edges = 147230, elasped_time = 35.44801735877991
# ranked_edges updated
# removed edges = 113000, total edges = 147230, elasped_time = 35.988178730010986
# ranked_edges updated
# removed edges = 114000, total edges = 147230, elasped_time = 35.713820457458496
# ranked_edges updated
# removed edges = 115000, total edges = 147230, elasped_time = 35.229639291763306
# ranked_edges updated
# removed edges = 116000, total edges = 147230, elasped_time = 37.10184383392334
# ranked_edges updated
# removed edges = 117000, total edges = 147230, elasped_time = 37.94334673881531
# ranked_edges updated
# removed edges = 118000, total edges = 147230, elasped_time = 37.28990817070007
# ranked_edges updated
# removed edges = 119000, total edges = 147230, elasped_time = 37.67001128196716
# ranked_edges updated
# removed edges = 120000, total edges = 147230, elasped_time = 38.60098576545715
# ranked_edges updated
# removed edges = 121000, total edges = 147230, elasped_time = 38.18187475204468
# ranked_edges updated
# removed edges = 122000, total edges = 147230, elasped_time = 39.321860551834106
# ranked_edges updated
# removed edges = 123000, total edges = 147230, elasped_time = 39.40152025222778
# ranked_edges updated
# removed edges = 124000, total edges = 147230, elasped_time = 39.890689849853516
# ranked_edges updated
# removed edges = 125000, total edges = 147230, elasped_time = 39.86029028892517
# ranked_edges updated
# removed edges = 126000, total edges = 147230, elasped_time = 40.3731689453125
# ranked_edges updated
# removed edges = 127000, total edges = 147230, elasped_time = 40.860103368759155
# ranked_edges updated
# removed edges = 128000, total edges = 147230, elasped_time = 40.837780714035034
# ranked_edges updated
# removed edges = 129000, total edges = 147230, elasped_time = 41.16065502166748
# ranked_edges updated
# removed edges = 130000, total edges = 147230, elasped_time = 41.15301704406738
# ranked_edges updated
# removed edges = 131000, total edges = 147230, elasped_time = 41.03461790084839
# ranked_edges updated
# removed edges = 132000, total edges = 147230, elasped_time = 41.91318440437317
# ranked_edges updated
# removed edges = 133000, total edges = 147230, elasped_time = 42.04432010650635
# ranked_edges updated
# removed edges = 134000, total edges = 147230, elasped_time = 42.340818643569946
# ranked_edges updated
# removed edges = 135000, total edges = 147230, elasped_time = 43.504188537597656
# ranked_edges updated
# removed edges = 136000, total edges = 147230, elasped_time = 43.56551790237427
# ranked_edges updated
# removed edges = 137000, total edges = 147230, elasped_time = 43.69109320640564
# ranked_edges updated
# removed edges = 138000, total edges = 147230, elasped_time = 44.91916799545288
# ranked_edges updated
# removed edges = 139000, total edges = 147230, elasped_time = 44.76494359970093
# ranked_edges updated
# removed edges = 140000, total edges = 147230, elasped_time = 45.26268792152405
# ranked_edges updated
# removed edges = 141000, total edges = 147230, elasped_time = 46.24984169006348
# ranked_edges updated
# removed edges = 142000, total edges = 147230, elasped_time = 46.667542695999146
# ranked_edges updated
# removed edges = 143000, total edges = 147230, elasped_time = 47.29175925254822
# ranked_edges updated
# removed edges = 144000, total edges = 147230, elasped_time = 48.38343286514282
# ranked_edges updated
# removed edges = 145000, total edges = 147230, elasped_time = 48.893768548965454
# ranked_edges updated
# removed edges = 146000, total edges = 147230, elasped_time = 49.78526496887207
# ranked_edges updated
# removed edges = 147000, total edges = 147230, elasped_time = 49.784770488739014
# ranked_edges updated

# %%
import pickle
dir = "c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/"

with open(f'{dir}removed_edges_overlap_decreasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(rn, file)

with open(f'{dir}components_overlap_decreasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(comps, file)

# %%
h = G.copy()
ef = dismantle_edge_overlap_2(h, repeat_rank = 250, reverse= False)
plot_dismantle(rn, comps)
# Out:
# removed edges = 0, total edges = 147230, elasped_time = 0.0
# ranked_edges updated
# ranked_edges updated
# ranked_edges updated
# ranked_edges updated
# removed edges =

plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,1,1)
plt.plot(np.array(rn['ee'])/rn['ee'][0], label='ee')
plt.plot(np.array(rn['ii'])/rn['ii'][0], label='ii')
plt.plot(np.array(rn['ei'])/rn['ei'][0], label='ei')
plt.ylabel("Fraction of removed edges size")
plt.legend()
plt.subplot(2,1,2)
plt.plot(np.array(ef['ee'])/ef['ee'][0], label='ee')
plt.plot(np.array(ef['ii'])/ef['ii'][0], label='ii')
plt.plot(np.array(ef['ei'])/ef['ei'][0], label='ei')
plt.xlabel("Step")
plt.ylabel("Fraction of removed edges size")
plt.legend()
plt.show()

# %%
import pickle
dir = "c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/"

with open(f'{dir}edge_fraction_overlap_increasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(ef, file)

# %%
h = G.copy()
rn, comps = dismantle_edge_score(h, 'duration')
plot_dismantle(rn, comps)
# Out:
# removed edges = 0, total edges = 147230, elapsed_time = 0.0
# removed edges = 1000, total edges = 147230, elapsed_time = 46.11275029182434
# removed edges = 2000, total edges = 147230, elapsed_time = 37.30766034126282
# removed edges = 3000, total edges = 147230, elapsed_time = 36.78842043876648
# removed edges = 4000, total edges = 147230, elapsed_time = 36.086095333099365
# removed edges = 5000, total edges = 147230, elapsed_time = 38.51715087890625
# removed edges = 6000, total edges = 147230, elapsed_time = 37.26805305480957
# removed edges = 7000, total edges = 147230, elapsed_time = 36.01071119308472
# removed edges = 8000, total edges = 147230, elapsed_time = 48.656484842300415
# removed edges = 9000, total edges = 147230, elapsed_time = 45.217238426208496
# removed edges = 10000, total edges = 147230, elapsed_time = 36.443984508514404
# removed edges = 11000, total edges = 147230, elapsed_time = 37.52392768859863
# removed edges = 12000, total edges = 147230, elapsed_time = 36.03267478942871
# removed edges = 13000, total edges = 147230, elapsed_time = 36.56592082977295
# removed edges = 14000, total edges = 147230, elapsed_time = 37.065680742263794
# removed edges = 15000, total edges = 147230, elapsed_time = 36.61972784996033
# removed edges = 16000, total edges = 147230, elapsed_time = 45.8613600730896
# removed edges = 17000, total edges = 147230, elapsed_time = 44.212626218795776
# removed edges = 18000, total edges = 147230, elapsed_time = 45.93622446060181
# removed edges = 19000, total edges = 147230, elapsed_time = 43.27859091758728
# removed edges = 20000, total edges = 147230, elapsed_time = 39.32083511352539
# removed edges = 21000, total edges = 147230, elapsed_time = 37.66067314147949
# removed edges = 22000, total edges = 147230, elapsed_time = 36.53671598434448
# removed edges = 23000, total edges = 147230, elapsed_time = 37.19427442550659
# removed edges = 24000, total edges = 147230, elapsed_time = 35.58875107765198
# removed edges = 25000, total edges = 147230, elapsed_time = 36.09976315498352
# removed edges = 26000, total edges = 147230, elapsed_time = 36.18695855140686
# removed edges = 27000, total edges = 147230, elapsed_time = 38.40069127082825
# removed edges = 28000, total edges = 147230, elapsed_time = 36.5570433139801
# removed edges = 29000, total edges = 147230, elapsed_time = 37.19097065925598
# removed edges = 30000, total edges = 147230, elapsed_time = 34.389301776885986
# removed edges = 31000, total edges = 147230, elapsed_time = 36.336952686309814
# removed edges = 32000, total edges = 147230, elapsed_time = 35.77665662765503
# removed edges = 33000, total edges = 147230, elapsed_time = 36.366955280303955
# removed edges = 34000, total edges = 147230, elapsed_time = 36.022106409072876
# removed edges = 35000, total edges = 147230, elapsed_time = 36.1145339012146
# removed edges = 125000, total edges = 147230, elapsed_time = 52.25184679031372
# removed edges = 126000, total edges = 147230, elapsed_time = 42.80009937286377
# removed edges = 127000, total edges = 147230, elapsed_time = 43.18191075325012
# removed edges = 128000, total edges = 147230, elapsed_time = 43.38544249534607
# removed edges = 129000, total edges = 147230, elapsed_time = 42.69238066673279
# removed edges = 130000, total edges = 147230, elapsed_time = 42.80901551246643
# removed edges = 131000, total edges = 147230, elapsed_time = 42.873823165893555
# removed edges = 132000, total edges = 147230, elapsed_time = 43.129231452941895
# removed edges = 133000, total edges = 147230, elapsed_time = 43.53809428215027
# removed edges = 134000, total edges = 147230, elapsed_time = 45.116244077682495
# removed edges = 135000, total edges = 147230, elapsed_time = 44.93975758552551
# removed edges = 136000, total edges = 147230, elapsed_time = 45.63192319869995
# removed edges = 137000, total edges = 147230, elapsed_time = 45.66525340080261
# removed edges = 138000, total edges = 147230, elapsed_time = 46.34506392478943
# removed edges = 139000, total edges = 147230, elapsed_time = 46.416348934173584
# removed edges = 140000, total edges = 147230, elapsed_time = 46.81301474571228
# removed edges = 141000, total edges = 147230, elapsed_time = 47.541616439819336
# removed edges = 142000, total edges = 147230, elapsed_time = 48.454649925231934
# removed edges = 143000, total edges = 147230, elapsed_time = 48.47115468978882
# removed edges = 144000, total edges = 147230, elapsed_time = 49.07072305679321
# removed edges = 145000, total edges = 147230, elapsed_time = 49.410346031188965
# removed edges = 146000, total edges = 147230, elapsed_time = 50.62692928314209
# removed edges = 147000, total edges = 147230, elapsed_time = 62.56724262237549

# %%
import pickle
dir = "c:/Users/HP/Desktop/UNI/LM_1/SNA/SNA/data/"

with open(f'{dir}removed_edges_duration_decreasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(rn, file)

with open(f'{dir}components_overlap_duration_decreasing.pkl', 'wb') as file:
    # Serialize the object and write it to the file
    pickle.dump(comps, file)

# %%
h = G.copy()
rn, comps = dismantle_edge_score(h, 'duration', reverse=False)
plot_dismantle(rn, comps)
# Out:
# removed edges = 0, total edges = 147230, elapsed_time = 0.0
# removed edges = 1000, total edges = 147230, elapsed_time = 60.36476993560791
# removed edges = 2000, total edges = 147230, elapsed_time = 58.63358235359192
# removed edges = 3000, total edges = 147230, elapsed_time = 46.03474020957947
# removed edges = 4000, total edges = 147230, elapsed_time = 62.778000354766846
# removed edges = 5000, total edges = 147230, elapsed_time = 66.6397922039032
# removed edges = 6000, total edges = 147230, elapsed_time = 43.35968804359436
# removed edges = 7000, total edges = 147230, elapsed_time = 48.47146201133728
# removed edges = 8000, total edges = 147230, elapsed_time = 45.49954557418823
# removed edges = 9000, total edges = 147230, elapsed_time = 60.37544631958008
# removed edges = 10000, total edges = 147230, elapsed_time = 62.36299395561218
# removed edges = 11000, total edges = 147230, elapsed_time = 62.456409215927124
# removed edges = 12000, total edges = 147230, elapsed_time = 43.59014296531677
# removed edges = 13000, total edges = 147230, elapsed_time = 52.064741373062134
# removed edges = 14000, total edges = 147230, elapsed_time = 60.55463361740112
# removed edges = 15000, total edges = 147230, elapsed_time = 60.00973892211914
# removed edges = 16000, total edges = 147230, elapsed_time = 72.0647623538971
# removed edges = 17000, total edges = 147230, elapsed_time = 63.534950494766235
